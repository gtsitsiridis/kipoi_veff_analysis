# %%
from kipoi_aparent2.dataloader import VCFApaDataloader
from kipoi_aparent2.dataloader.apa_annotation import EnsemblAPAAnnotation
from pathlib import Path
import polars as pl

# %%
FASTA_FILE = Path('/s/genomes/Gencode/Gencode_human/release_40/GRCh37_mapping/GRCh37.primary_assembly.genome.fa')
GTF_FILE = Path('/s/genomes/Gencode/Gencode_human/release_40/GRCh37_mapping/gencode.v40lift37.annotation.gtf.gz')
VCF_DIR = Path('/s/project/rep/processed/training_results_v14/distinct_variants.valid_snp_indel.vcf.restored/distinct_variants.valid_snp_indel.vcf/')

# %%
VCF_FILES = list(VCF_DIR.glob('*.vcf.gz'))

# %%
APA_ANNOTATION = EnsemblAPAAnnotation(GTF_FILE, canonical_only=False, protein_coding_only=True)

# %%
def vcf_to_polars(vcf_file, variant_upstream_cse=70, variant_downstream_cse=130,
                  canonical_only=False, protein_coding_only=True):
    dataloader = VCFApaDataloader(vcf_file=vcf_file, variant_upstream_cse=variant_upstream_cse,
                                  variant_downstream_cse=variant_downstream_cse,
                                  fasta_file=FASTA_FILE, apa_annotation=APA_ANNOTATION,
                                  seq_length=10000, cse_pos_index=3000)
    return pl.DataFrame(dataloader.load_all()['metadata']). \
        select(pl.exclude(['seq_start', 'seq_end'])). \
        with_columns(vcf_file=pl.lit(str(vcf_file)))

# %%
variant_df = pl.concat([vcf_to_polars(vcf_file) for vcf_file in VCF_FILES])
# Out:
# 6it [00:01,  4.98it/s]
# 14it [00:01, 11.18it/s]
# 19it [00:01, 14.45it/s]
# 18it [00:01, 13.76it/s]
# 12it [00:01,  9.32it/s]
# 93it [00:02, 40.92it/s]
# 18it [00:01, 13.40it/s]
# 17it [00:01, 11.62it/s]
# 13it [00:01,  9.94it/s]
# 11it [00:01,  9.09it/s]
# 11it [00:01,  8.87it/s]
# 12it [00:01, 10.24it/s]
# 7it [00:01,  6.16it/s]
# 8it [00:01,  7.58it/s]
# 9it [00:01,  6.52it/s]
# 7it [00:01,  5.69it/s]
# 15it [00:01, 12.49it/s]
# 17it [00:01, 12.65it/s]
# 9it [00:01,  6.71it/s]
# 8it [00:01,  7.83it/s]
# 7it [00:01,  6.12it/s]
# 32it [00:01, 19.87it/s]
# 25it [00:01, 17.27it/s]
# 39it [00:01, 24.29it/s]
# 9it [00:01,  7.49it/s]
# 19it [00:01, 13.75it/s]
# 25it [00:01, 16.44it/s]
# 29it [00:01, 19.52it/s]
# 10it [00:01,  8.10it/s]
# 9it [00:01,  7.16it/s]
# 20it [00:01, 13.39it/s]
# 6it [00:01,  5.82it/s]
# 12it [00:01,  8.64it/s]
# 15it [00:01, 10.26it/s]
# 33it [00:01, 21.74it/s]
# 15it [00:01, 11.63it/s]
# 10it [00:01,  8.08it/s]
# 6it [00:01,  4.79it/s]
# 58it [00:01, 30.78it/s]
# 15it [00:01, 10.35it/s]
# 8it [00:01,  6.58it/s]
# 14it [00:01, 11.43it/s]
# 34it [00:01, 23.36it/s]
# 8it [00:01,  6.20it/s]
# 9it [00:01,  7.66it/s]
# 14it [00:01, 11.84it/s]
# 4it [00:01,  3.73it/s]
# 12it [00:01,  8.81it/s]
# 14it [00:01, 10.58it/s]
# 5it [00:01,  4.71it/s]
# 38it [00:01, 19.54it/s]
# 33it [00:01, 20.13it/s]
# 14it [00:01, 12.48it/s]
# 30it [00:01, 18.92it/s]
# 14it [00:01, 11.59it/s]
# 23it [00:01, 16.71it/s]
# 5it [00:01,  3.81it/s]
# 20it [00:01, 14.28it/s]
# 40it [00:01, 24.10it/s]
# 9it [00:01,  7.77it/s]
# 10it [00:01,  7.86it/s]
# 7it [00:01,  6.50it/s]
# 21it [00:01, 15.18it/s]
# 40it [00:01, 25.80it/s]
# 8it [00:01,  6.58it/s]
# 15it [00:01, 11.53it/s]
# 9it [00:01,  7.60it/s]
# 1it [00:01,  1.19s/it]
# 14it [00:01, 10.63it/s]
# 15it [00:01, 11.47it/s]
# 5it [00:01,  3.92it/s]
# 10it [00:01,  7.85it/s]
# 23it [00:01, 17.73it/s]
# 35it [00:01, 21.87it/s]
# 10it [00:01,  8.34it/s]
# 37it [00:01, 22.12it/s]
# 8it [00:01,  6.55it/s]
# 14it [00:01, 11.59it/s]
# 9it [00:01,  8.39it/s]
# 10it [00:01,  8.09it/s]
# 10it [00:01,  8.54it/s]
# 19it [00:01, 14.44it/s]
# 3it [00:00,  3.32it/s]
# 21it [00:01, 15.38it/s]
# 14it [00:01, 10.93it/s]
# 18it [00:01, 15.65it/s]
# 11it [00:01,  8.39it/s]
# 7it [00:01,  5.79it/s]
# 18it [00:01, 13.51it/s]
# 7it [00:01,  6.70it/s]
# 12it [00:01, 10.46it/s]
# 14it [00:01,  9.94it/s]
# 47it [00:01, 26.37it/s]
# 20it [00:01, 15.09it/s]
# 15it [00:01, 11.57it/s]
# 7it [00:01,  6.82it/s]
# 30it [00:01, 20.91it/s]
# 51it [00:01, 31.30it/s]
# 10it [00:01,  8.97it/s]
# 22it [00:01, 17.62it/s]
# 26it [00:01, 19.45it/s]
# 2it [00:00,  2.17it/s]
# 2it [00:00,  2.16it/s]
# 6it [00:01,  4.86it/s]
# 8it [00:01,  7.00it/s]
# 9it [00:01,  8.75it/s]
# 13it [00:01, 11.62it/s]
# 3it [00:00,  3.33it/s]
# 18it [00:01, 15.05it/s]
# 15it [00:01, 11.50it/s]
# 7it [00:01,  6.34it/s]
# 5it [00:01,  4.69it/s]
# 9it [00:01,  7.63it/s]
# 16it [00:01, 13.67it/s]
# 9it [00:01,  8.32it/s]
# 21it [00:01, 14.92it/s]
# 7it [00:00,  7.50it/s]
# 33it [00:01, 21.20it/s]
# 6it [00:01,  5.08it/s]
# 34it [00:01, 23.87it/s]
# 4it [00:01,  3.67it/s]
# 31it [00:01, 20.07it/s]
# 10it [00:01,  8.17it/s]
# 9it [00:01,  8.37it/s]
# 10it [00:01,  8.14it/s]
# 6it [00:01,  5.08it/s]
# 10it [00:01,  9.41it/s]
# 4it [00:01,  3.87it/s]
# 18it [00:01, 14.80it/s]
# 22it [00:01, 17.84it/s]
# 5it [00:01,  3.98it/s]
# 16it [00:01, 12.21it/s]
# 6it [00:01,  5.23it/s]
# 9it [00:00,  9.69it/s]
# 30it [00:01, 22.03it/s]
# 5it [00:00,  5.25it/s]
# 9it [00:01,  7.38it/s]
# 10it [00:01,  8.85it/s]
# 28it [00:01, 20.90it/s]
# 26it [00:01, 20.17it/s]
# 20it [00:01, 12.19it/s]
# 20it [00:01, 16.82it/s]
# 8it [00:01,  5.40it/s]
# 15it [00:01, 12.48it/s]
# 5it [00:01,  4.40it/s]
# 7it [00:01,  6.75it/s]
# 16it [00:01, 12.65it/s]
# 10it [00:01,  9.85it/s]
# 10it [00:01,  8.56it/s]
# 16it [00:01, 13.49it/s]
# 7it [00:01,  6.26it/s]
# 6it [00:01,  5.42it/s]
# 23it [00:01, 16.86it/s]
# 4it [00:00,  4.20it/s]
# 27it [00:01, 17.98it/s]
# 9it [00:00,  9.37it/s]
# 63it [00:01, 35.04it/s]
# 19it [00:01, 14.70it/s]
# 25it [00:01, 17.38it/s]
# 13it [00:01, 11.79it/s]
# 6it [00:00,  6.04it/s]
# 8it [00:01,  7.77it/s]
# 12it [00:01,  9.96it/s]
# 66it [00:01, 34.98it/s]
# 12it [00:01,  9.27it/s]
# 21it [00:01, 13.66it/s]
# 9it [00:01,  8.68it/s]
# 9it [00:01,  8.79it/s]
# 10it [00:01,  9.42it/s]
# 8it [00:01,  7.47it/s]
# 13it [00:01, 11.02it/s]
# 11it [00:01,  9.47it/s]
# 16it [00:01, 14.15it/s]
# 20it [00:01, 15.73it/s]
# 25it [00:01, 17.02it/s]
# 12it [00:01, 10.50it/s]
# 22it [00:01, 17.79it/s]
# 14it [00:01, 11.83it/s]
# 6it [00:01,  5.53it/s]
# 13it [00:01, 10.46it/s]
# 17it [00:01, 15.86it/s]
# 46it [00:01, 27.21it/s]
# 20it [00:01, 16.51it/s]
# 15it [00:01, 11.24it/s]
# 11it [00:01,  9.22it/s]
# 6it [00:01,  5.77it/s]
# 8it [00:01,  7.60it/s]
# 9it [00:01,  7.15it/s]
# 20it [00:01, 16.25it/s]
# 7it [00:01,  6.49it/s]
# 7it [00:01,  6.21it/s]
# 13it [00:01,  9.77it/s]
# 3it [00:01,  2.34it/s]
# 36it [00:01, 23.96it/s]
# 59it [00:02, 28.33it/s]
# 12it [00:01,  9.58it/s]
# 25it [00:01, 18.72it/s]
# 13it [00:01, 10.13it/s]
# 54it [00:01, 31.46it/s]
# 15it [00:01, 13.03it/s]
# 12it [00:01, 11.15it/s]
# 35it [00:01, 21.85it/s]
# 7it [00:01,  5.91it/s]
# 7it [00:01,  6.89it/s]
# 10it [00:00, 10.37it/s]
# 7it [00:01,  6.25it/s]
# 6it [00:00,  6.20it/s]
# 7it [00:01,  6.60it/s]
# 7it [00:01,  5.67it/s]
# 29it [00:01, 19.48it/s]
# 52it [00:01, 30.05it/s]
# 11it [00:01,  9.59it/s]
# 6it [00:01,  5.91it/s]
# 8it [00:01,  7.35it/s]
# 43it [00:01, 28.73it/s]
# 6it [00:01,  5.84it/s]
# 12it [00:01, 10.79it/s]
# 8it [00:00,  8.46it/s]
# 40it [00:01, 24.37it/s]
# 9it [00:01,  5.80it/s]
# 66it [00:01, 35.81it/s]
# 11it [00:01, 10.16it/s]
# 4it [00:01,  3.60it/s]
# 5it [00:01,  4.77it/s]
# 34it [00:01, 23.30it/s]
# 67it [00:01, 35.54it/s]
# 7it [00:00,  7.22it/s]
# 18it [00:01, 15.60it/s]
# 9it [00:01,  8.04it/s]
# 12it [00:01,  9.55it/s]
# 23it [00:01, 18.14it/s]
# 8it [00:01,  6.54it/s]
# 7it [00:01,  5.91it/s]
# 21it [00:01, 16.38it/s]
# 8it [00:01,  6.38it/s]
# 25it [00:01, 19.27it/s]
# 16it [00:01, 11.74it/s]
# 5it [00:00,  5.33it/s]
# 9it [00:01,  8.51it/s]
# 5it [00:01,  4.86it/s]
# 7it [00:01,  6.57it/s]
# 12it [00:01, 11.81it/s]
# 7it [00:01,  6.41it/s]
# 19it [00:01, 16.83it/s]
# 8it [00:00,  8.09it/s]
# 6it [00:01,  5.99it/s]
# 12it [00:01, 10.84it/s]
# 38it [00:01, 27.71it/s]
# 8it [00:01,  7.35it/s]
# 22it [00:01, 16.95it/s]
# 13it [00:01, 11.32it/s]
# 22it [00:01, 15.12it/s]
# 4it [00:01,  3.87it/s]
# 14it [00:01, 12.61it/s]
# 3it [00:00,  3.07it/s]
# 13it [00:01, 11.13it/s]
# 15it [00:01, 12.88it/s]
# 7it [00:01,  6.34it/s]
# 30it [00:01, 21.77it/s]
# 10it [00:01,  8.83it/s]
# 21it [00:01, 16.88it/s]
# 5it [00:00,  5.12it/s]
# 10it [00:01,  9.76it/s]
# 1it [00:01,  1.03s/it]
# 1it [00:00,  1.00it/s]
# 5it [00:01,  4.63it/s]
# 4it [00:00,  4.16it/s]
# 9it [00:00,  9.45it/s]
# 9it [00:01,  8.27it/s]
# 23it [00:01, 18.60it/s]
# 9it [00:00,  9.19it/s]
# 9it [00:00,  9.19it/s]
# 16it [00:01, 12.06it/s]
# 3it [00:00,  3.08it/s]
# 41it [00:01, 26.58it/s]
# 9it [00:01,  8.49it/s]
# 20it [00:01, 16.47it/s]
# 48it [00:01, 30.37it/s]
# 21it [00:01, 15.75it/s]
# 16it [00:01, 13.54it/s]
# 1it [00:00,  1.10it/s]
# 12it [00:00, 12.26it/s]
# 42it [00:01, 28.93it/s]
# 9it [00:00,  9.07it/s]
# 22it [00:01, 14.38it/s]
# 7it [00:00,  7.49it/s]
# 12it [00:01, 10.17it/s]
# 18it [00:01, 14.92it/s]
# 31it [00:01, 22.00it/s]
# 18it [00:01, 14.37it/s]
# 11it [00:01, 10.99it/s]
# 28it [00:01, 20.99it/s]
# 13it [00:01, 10.37it/s]
# 16it [00:01, 13.51it/s]
# 19it [00:01, 15.76it/s]
# 4it [00:01,  3.79it/s]
# 72it [00:01, 36.77it/s]
# 10it [00:01,  9.29it/s]
# 37it [00:01, 24.73it/s]
# 23it [00:01, 18.68it/s]
# 4it [00:00,  4.06it/s]
# 9it [00:01,  8.27it/s]
# 12it [00:01, 11.80it/s]
# 8it [00:01,  7.49it/s]
# 2it [00:00,  2.14it/s]
# 7it [00:01,  6.56it/s]
# 64it [00:01, 34.47it/s]
# 8it [00:00,  8.41it/s]
# 8it [00:01,  7.00it/s]
# 13it [00:01, 11.93it/s]
# 16it [00:01, 13.45it/s]
# 5it [00:00,  5.12it/s]
# 6it [00:01,  5.93it/s]
# 7it [00:01,  6.58it/s]
# 78it [00:01, 40.53it/s]
# 12it [00:01, 10.24it/s]
# 47it [00:01, 28.85it/s]
# 1it [00:00,  1.03it/s]
# 23it [00:01, 16.96it/s]
# 11it [00:01,  9.47it/s]
# 7it [00:01,  5.23it/s]
# 5it [00:01,  4.82it/s]

# %%
variant_df.head()
# Out:
# shape: (5, 12)
# ┌──────────┬──────────┬───────┬────────┬─────┬─────────────┬─────┬─────┬───────────────────────────┐
# │ pas_pos  ┆ cse_pos  ┆ chrom ┆ strand ┆ ... ┆ variant_end ┆ ref ┆ alt ┆ vcf_file                  │
# │ ---      ┆ ---      ┆ ---   ┆ ---    ┆     ┆ ---         ┆ --- ┆ --- ┆ ---                       │
# │ i64      ┆ i64      ┆ str   ┆ str    ┆     ┆ i64         ┆ str ┆ str ┆ str                       │
# ╞══════════╪══════════╪═══════╪════════╪═════╪═════════════╪═════╪═════╪═══════════════════════════╡
# │ 70320621 ┆ 70320591 ┆ chrX  ┆ +      ┆ ... ┆ 70320653    ┆ C   ┆ T   ┆ /s/project/rep/processed/ │
# │          ┆          ┆       ┆        ┆     ┆             ┆     ┆     ┆ trainin...                │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 70320692 ┆ 70320662 ┆ chrX  ┆ +      ┆ ... ┆ 70320653    ┆ C   ┆ T   ┆ /s/project/rep/processed/ │
# │          ┆          ┆       ┆        ┆     ┆             ┆     ┆     ┆ trainin...                │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 70344909 ┆ 70344879 ┆ chrX  ┆ +      ┆ ... ┆ 70344990    ┆ C   ┆ T   ┆ /s/project/rep/processed/ │
# │          ┆          ┆       ┆        ┆     ┆             ┆     ┆     ┆ trainin...                │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 70346805 ┆ 70346775 ┆ chrX  ┆ +      ┆ ... ┆ 70346869    ┆ G   ┆ A   ┆ /s/project/rep/processed/ │
# │          ┆          ┆       ┆        ┆     ┆             ┆     ┆     ┆ trainin...                │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 70346814 ┆ 70346784 ┆ chrX  ┆ +      ┆ ... ┆ 70346869    ┆ G   ┆ A   ┆ /s/project/rep/processed/ │
# │          ┆          ┆       ┆        ┆     ┆             ┆     ┆     ┆ trainin...                │
# └──────────┴──────────┴───────┴────────┴─────┴─────────────┴─────┴─────┴───────────────────────────┘

# %%
variant_df.shape
# Out:
# (163448, 12)

# %%
variant_df.write_parquet('/data/nasif12/home_if12/tsi/kipoi_expression_prediction/variant_tables/apa_variants_70_130.parquet')

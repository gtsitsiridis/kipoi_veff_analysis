# %%
library(IRdisplay)
library(Cairo)

library(data.table)
library(arrow)
library(ggplot2)
library(cowplot)
library(ggrepel)
library(ggthemes)
library(ggpubr)
library(ggtext)
library(patchwork)
library(grid)
library(gridExtra)
library(scales)
library(stringr)
library(RColorBrewer)
library(yaml)
library(plyr)
# library(dplyr)
library(tidyverse)
library(ggnewscale)
library(png)
library(rstatix)
# Out:
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘ggthemes’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     theme_map
#
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
#
# Attaching package: ‘plyr’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     mutate
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()      masks plyr::arrange()
# ✖ dplyr::between()      masks data.table::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ dplyr::combine()      masks gridExtra::combine()
# ✖ purrr::compact()      masks plyr::compact()
# ✖ dplyr::count()        masks plyr::count()
# ✖ dplyr::desc()         masks plyr::desc()
# ✖ purrr::discard()      masks scales::discard()
# ✖ lubridate::duration() masks arrow::duration()
# ✖ dplyr::failwith()     masks plyr::failwith()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ dplyr::first()        masks data.table::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ dplyr::id()           masks plyr::id()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ dplyr::last()         masks data.table::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ dplyr::mutate()       masks plyr::mutate(), ggpubr::mutate()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ dplyr::rename()       masks plyr::rename()
# ✖ lubridate::second()   masks data.table::second()
# ✖ lubridate::stamp()    masks cowplot::stamp()
# ✖ dplyr::summarise()    masks plyr::summarise()
# ✖ dplyr::summarize()    masks plyr::summarize()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘rstatix’
#
#
# The following objects are masked from ‘package:plyr’:
#
#     desc, mutate
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
LINESIZE = .3
FONTSIZE = 12
THEME = theme_cowplot(font_size = FONTSIZE, font_family = 'Helvetica') + theme(plot.tag = element_text(face = "bold"))

# %%
output_path = '/data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots'

# %%
base_path <- '/data/nasif12/home_if12/tsi/training_results_v16/gtex_v8_old_dna/predict_folds/subset=all/plots/compare_results.py@dna_only_splice_sv_dups_Enformer_Aparent2_SpeciesLM/overexpression'

# %%
# %%
superscript_mapping = c(
    `-` = '⁻',
    `+` = "", # ⁺
    `0` = "\u2070",
    `1` = "\u00B9",
    `2` = "\u00B2",
    `3` = "\u00B3",
    `4` = "\u2074",
    `5` = "\u2075",
    `6` = "\u2076",
    `7` = "\u2077",
    `8` = "\u2078",
    `9` = "\u2079"
)

# %%
fancy_scientific <- function(l, digits=NULL, low=1/1000, high=1000) {
    # turn in to character string in scientific notation
    l = as.numeric(l)
    if (is.na(l)) {
        return("NA")
    }
    if (l == 0) {
        return("0")
    }
    if ((low < l) & (l < high)){
        return(format(l, scientific=FALSE, digits=digits, big.mark=",", trim=TRUE))
    }
    l = format(l, scientific=TRUE, digits=digits)

    # l <- format(l, scientific = TRUE)
    # split into factor and exponent
    l_split = strsplit(l, 'e')[[1]]
    if (! is.null(digits)) {
        l_split[1] = round(as.numeric(l_split[1]), digits)
    }
    # make exponent superscript
    l_split[2] = as.numeric(l_split[2])
    l_split[2] = paste(
        lapply(strsplit(l_split[2], "")[[1]], function(x) noquote(superscript_mapping[[x]])),
        collapse=''
    )
    # concat everything
    l_split = paste0(l_split[1], "x10", l_split[2])

    l_split
}

# %%
all_lower = function(df, model_col, value_col, comp_x, comp_y){
    val_x = df[[value_col]][df[[model_col]] == comp_x]
    val_y = df[[value_col]][df[[model_col]] == comp_y]
    return(all(val_x < val_y))
}

# %%
selected_models = c(
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer"
)
selected_models
# Out:
# [1] "LOFTEE+CADD+weighted csq.+disp.+AbSplice"
# [2] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2"
# [3] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM"
# [4] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer"

# %%
rename_models = list(
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice` = 'AbExp',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss` = 'AbExp\n+ TSS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas` = 'AbExp\n+ PAS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss` = 'AbExp\n+ PAS + TSS',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer` = 'AbExp\n+ Enformer',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2` = 'AbExp\n+ Aparent2',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM` = 'AbExp\n+ SpeciesLM'
)

# %%
# sapply(comparisons, function(x) x[1] %in% rename_models & x[2] %in% rename_models )

# %%
# rename_models = as.list(selected_models)
# names(rename_models) = rename_models

# %%
rename_models
# Out:
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice`
# [1] "AbExp"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer`
# [1] "AbExp\n+ Enformer"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2`
# [1] "AbExp\n+ Aparent2"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM`
# [1] "AbExp\n+ SpeciesLM"

# %%
prc_df = as.data.table(read_parquet(file.path(base_path, "/prc_df.parquet")))
prc_df = prc_df[`model` %in% selected_models]
model_idx = unique(prc_df[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
prc_df$model <- factor(prc_df$model, levels=model_idx$model)
prc_df$model <- recode(prc_df$model, !!!rename_models)
prc_df
# Out:
#      precision recall threshold is_binary auc          model
# 1    0.0000    0e+00  3.4447137 FALSE     0.000161198  AbExp
# 2    0.0065    1e-04  1.0270481 FALSE     0.000161198  AbExp
# 3    0.0064    1e-04  1.0092514 FALSE     0.000161198  AbExp
# 4    0.0063    1e-04  1.0037077 FALSE     0.000161198  AbExp
# 5    0.0062    1e-04  0.9820029 FALSE     0.000161198  AbExp
# 6    0.0061    1e-04  0.9754261 FALSE     0.000161198  AbExp
# 7    0.0059    1e-04  0.9744582 FALSE     0.000161198  AbExp
# 8    0.0058    1e-04  0.9742513 FALSE     0.000161198  AbExp
# 9    0.0057    1e-04  0.9442046 FALSE     0.000161198  AbExp
# 10   0.0052    1e-04  0.9261032 FALSE     0.000161198  AbExp
# 11   0.0051    1e-04  0.9230166 FALSE     0.000161198  AbExp
# 12   0.0049    1e-04  0.9170077 FALSE     0.000161198  AbExp
# 13   0.0048    1e-04  0.9064815 FALSE     0.000161198  AbExp
# 14   0.0047    1e-04  0.8859051 FALSE     0.000161198  AbExp
# 15   0.0046    1e-04  0.8574824 FALSE     0.000161198  AbExp
# 16   0.0045    1e-04  0.8364024 FALSE     0.000161198  AbExp
# 17   0.0044    1e-04  0.8322093 FALSE     0.000161198  AbExp
# 18   0.0043    1e-04  0.8132915 FALSE     0.000161198  AbExp
# 19   0.0042    1e-04  0.7820761 FALSE     0.000161198  AbExp
# 20   0.0041    1e-04  0.7712912 FALSE     0.000161198  AbExp
# 21   0.0040    1e-04  0.7669222 FALSE     0.000161198  AbExp
# 22   0.0080    1e-04  0.7568056 FALSE     0.000161198  AbExp
# 23   0.0079    1e-04  0.7455618 FALSE     0.000161198  AbExp
# 24   0.0078    1e-04  0.7453286 FALSE     0.000161198  AbExp
# 25   0.0116    2e-04  0.7295306 FALSE     0.000161198  AbExp
# 26   0.0115    2e-04  0.7288037 FALSE     0.000161198  AbExp
# 27   0.0114    2e-04  0.7232700 FALSE     0.000161198  AbExp
# 28   0.0113    2e-04  0.7194515 FALSE     0.000161198  AbExp
# 29   0.0112    2e-04  0.7176638 FALSE     0.000161198  AbExp
# 30   0.0111    2e-04  0.7094901 FALSE     0.000161198  AbExp
# ⋮    ⋮         ⋮      ⋮         ⋮         ⋮            ⋮
# 6868 1e-04     0.9971 -1.351059 FALSE     0.0005235537 AbExp\n+ Enformer
# 6869 1e-04     0.9972 -1.380516 FALSE     0.0005235537 AbExp\n+ Enformer
# 6870 1e-04     0.9973 -1.407569 FALSE     0.0005235537 AbExp\n+ Enformer
# 6871 1e-04     0.9974 -1.416191 FALSE     0.0005235537 AbExp\n+ Enformer
# 6872 1e-04     0.9975 -1.432027 FALSE     0.0005235537 AbExp\n+ Enformer
# 6873 1e-04     0.9976 -1.433794 FALSE     0.0005235537 AbExp\n+ Enformer
# 6874 1e-04     0.9977 -1.484006 FALSE     0.0005235537 AbExp\n+ Enformer
# 6875 1e-04     0.9978 -1.499748 FALSE     0.0005235537 AbExp\n+ Enformer
# 6876 1e-04     0.9979 -1.538744 FALSE     0.0005235537 AbExp\n+ Enformer
# 6877 1e-04     0.9980 -1.561651 FALSE     0.0005235537 AbExp\n+ Enformer
# 6878 1e-04     0.9981 -1.575946 FALSE     0.0005235537 AbExp\n+ Enformer
# 6879 1e-04     0.9982 -1.868662 FALSE     0.0005235537 AbExp\n+ Enformer
# 6880 1e-04     0.9983 -1.873589 FALSE     0.0005235537 AbExp\n+ Enformer
# 6881 1e-04     0.9984 -1.975822 FALSE     0.0005235537 AbExp\n+ Enformer
# 6882 1e-04     0.9985 -2.010766 FALSE     0.0005235537 AbExp\n+ Enformer
# 6883 1e-04     0.9986 -2.015369 FALSE     0.0005235537 AbExp\n+ Enformer
# 6884 1e-04     0.9987 -2.097637 FALSE     0.0005235537 AbExp\n+ Enformer
# 6885 1e-04     0.9988 -2.098771 FALSE     0.0005235537 AbExp\n+ Enformer
# 6886 1e-04     0.9989 -2.112068 FALSE     0.0005235537 AbExp\n+ Enformer
# 6887 1e-04     0.9990 -2.137867 FALSE     0.0005235537 AbExp\n+ Enformer
# 6888 1e-04     0.9991 -2.267792 FALSE     0.0005235537 AbExp\n+ Enformer
# 6889 1e-04     0.9992 -2.269875 FALSE     0.0005235537 AbExp\n+ Enformer
# 6890 1e-04     0.9993 -2.276901 FALSE     0.0005235537 AbExp\n+ Enformer
# 6891 1e-04     0.9994 -2.298156 FALSE     0.0005235537 AbExp\n+ Enformer
# 6892 1e-04     0.9995 -2.387614 FALSE     0.0005235537 AbExp\n+ Enformer
# 6893 1e-04     0.9996 -2.571646 FALSE     0.0005235537 AbExp\n+ Enformer
# 6894 1e-04     0.9997 -3.277438 FALSE     0.0005235537 AbExp\n+ Enformer
# 6895 1e-04     0.9998 -3.403318 FALSE     0.0005235537 AbExp\n+ Enformer
# 6896 1e-04     0.9999 -3.710423 FALSE     0.0005235537 AbExp\n+ Enformer
# 6897 1e-04     1.0000 -4.399563 FALSE     0.0005235537 AbExp\n+ Enformer
#      label                                                            idx
# 1    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 2    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 3    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 4    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 5    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 6    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 7    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 8    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 9    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 10   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 11   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 12   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 13   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 14   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 15   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 16   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 17   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 18   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 19   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 20   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 21   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 22   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 23   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 24   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 25   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 26   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 27   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 28   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 29   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# 30   LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(0.02% auPRC)          0
# ⋮    ⋮                                                                ⋮
# 6868 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6869 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6870 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6871 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6872 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6873 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6874 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6875 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6876 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6877 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6878 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6879 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6880 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6881 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6882 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6883 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6884 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6885 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6886 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6887 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6888 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6889 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6890 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6891 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6892 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6893 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6894 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6895 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6896 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3
# 6897 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(0.05% auPRC) 3

# %%
tissue_performance = as.data.table(read_parquet(file.path(base_path, "/performance.tissue.parquet")))
tissue_performance = tissue_performance[`model` %in% selected_models]
model_idx = unique(tissue_performance[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
tissue_performance$model <- factor(tissue_performance$model, levels=selected_models)
tissue_performance$model <- recode(tissue_performance$model, !!!rename_models)
tissue_performance
# Out:
#     model              tissue          auc          idx n_true auc_mean
# 1   AbExp              Adipose Tissue  2.344533e-04 0   1165   0.0003637894
# 2   AbExp              Adrenal Gland   1.330460e-03 0    224   0.0003637894
# 3   AbExp              Blood           2.284637e-04 0    587   0.0003637894
# 4   AbExp              Blood Vessel    2.294999e-04 0   1053   0.0003637894
# 5   AbExp              Brain           1.501075e-04 0   2041   0.0003637894
# 6   AbExp              Breast          1.407800e-04 0    426   0.0003637894
# 7   AbExp              Colon           2.614968e-04 0    672   0.0003637894
# 8   AbExp              Esophagus       1.718508e-04 0   1216   0.0003637894
# 9   AbExp              Heart           1.772671e-04 0    572   0.0003637894
# 10  AbExp              Kidney          3.371306e-05 0     10   0.0003637894
# 11  AbExp              Liver           7.136108e-05 0     82   0.0003637894
# 12  AbExp              Lung            1.404375e-04 0    592   0.0003637894
# 13  AbExp              Muscle          1.945521e-04 0    670   0.0003637894
# 14  AbExp              Nerve           4.289900e-04 0    686   0.0003637894
# 15  AbExp              Ovary           1.199058e-03 0    105   0.0003637894
# 16  AbExp              Pancreas        1.601827e-03 0    224   0.0003637894
# 17  AbExp              Pituitary       1.524862e-04 0    350   0.0003637894
# 18  AbExp              Prostate        1.769417e-04 0    183   0.0003637894
# 19  AbExp              Salivary Gland  1.095891e-03 0    104   0.0003637894
# 20  AbExp              Skin            1.606435e-04 0   1608   0.0003637894
# 21  AbExp              Small Intestine 8.983307e-05 0    142   0.0003637894
# 22  AbExp              Spleen          9.796188e-04 0    196   0.0003637894
# 23  AbExp              Stomach         1.161036e-04 0    273   0.0003637894
# 24  AbExp              Testis          1.074850e-04 0    339   0.0003637894
# 25  AbExp              Thyroid         2.399396e-04 0    803   0.0003637894
# 26  AbExp              Uterus          4.332407e-05 0     58   0.0003637894
# 27  AbExp              Vagina          6.572784e-05 0     83   0.0003637894
# 28  AbExp\n+ SpeciesLM Adipose Tissue  1.593304e-04 1   1165   0.0005064257
# 29  AbExp\n+ SpeciesLM Adrenal Gland   1.082571e-03 1    224   0.0005064257
# 30  AbExp\n+ SpeciesLM Blood           1.299502e-04 1    587   0.0005064257
# ⋮   ⋮                  ⋮               ⋮            ⋮   ⋮      ⋮
# 79  AbExp\n+ Aparent2  Thyroid         1.705544e-04 2    803   0.0002210287
# 80  AbExp\n+ Aparent2  Uterus          2.292545e-04 2     58   0.0002210287
# 81  AbExp\n+ Aparent2  Vagina          6.246907e-05 2     83   0.0002210287
# 82  AbExp\n+ Enformer  Adipose Tissue  2.344940e-04 3   1165   0.0008976440
# 83  AbExp\n+ Enformer  Adrenal Gland   2.541169e-03 3    224   0.0008976440
# 84  AbExp\n+ Enformer  Blood           2.043115e-04 3    587   0.0008976440
# 85  AbExp\n+ Enformer  Blood Vessel    7.582133e-04 3   1053   0.0008976440
# 86  AbExp\n+ Enformer  Brain           1.472524e-04 3   2041   0.0008976440
# 87  AbExp\n+ Enformer  Breast          2.576499e-03 3    426   0.0008976440
# 88  AbExp\n+ Enformer  Colon           1.782579e-03 3    672   0.0008976440
# 89  AbExp\n+ Enformer  Esophagus       4.912581e-04 3   1216   0.0008976440
# 90  AbExp\n+ Enformer  Heart           7.566001e-04 3    572   0.0008976440
# 91  AbExp\n+ Enformer  Kidney          3.906669e-05 3     10   0.0008976440
# 92  AbExp\n+ Enformer  Liver           2.533049e-03 3     82   0.0008976440
# 93  AbExp\n+ Enformer  Lung            1.994599e-03 3    592   0.0008976440
# 94  AbExp\n+ Enformer  Muscle          1.866403e-03 3    670   0.0008976440
# 95  AbExp\n+ Enformer  Nerve           1.309962e-03 3    686   0.0008976440
# 96  AbExp\n+ Enformer  Ovary           3.786987e-04 3    105   0.0008976440
# 97  AbExp\n+ Enformer  Pancreas        1.101499e-03 3    224   0.0008976440
# 98  AbExp\n+ Enformer  Pituitary       1.559339e-04 3    350   0.0008976440
# 99  AbExp\n+ Enformer  Prostate        1.676135e-04 3    183   0.0008976440
# 100 AbExp\n+ Enformer  Salivary Gland  2.989517e-04 3    104   0.0008976440
# 101 AbExp\n+ Enformer  Skin            5.776965e-04 3   1608   0.0008976440
# 102 AbExp\n+ Enformer  Small Intestine 1.500232e-04 3    142   0.0008976440
# 103 AbExp\n+ Enformer  Spleen          9.965878e-04 3    196   0.0008976440
# 104 AbExp\n+ Enformer  Stomach         1.699095e-04 3    273   0.0008976440
# 105 AbExp\n+ Enformer  Testis          3.089076e-04 3    339   0.0008976440
# 106 AbExp\n+ Enformer  Thyroid         1.533921e-03 3    803   0.0008976440
# 107 AbExp\n+ Enformer  Uterus          5.230041e-04 3     58   0.0008976440
# 108 AbExp\n+ Enformer  Vagina          6.381858e-04 3     83   0.0008976440
#     auc_median   auc_std
# 1   0.0001769417 0.0004436599
# 2   0.0001769417 0.0004436599
# 3   0.0001769417 0.0004436599
# 4   0.0001769417 0.0004436599
# 5   0.0001769417 0.0004436599
# 6   0.0001769417 0.0004436599
# 7   0.0001769417 0.0004436599
# 8   0.0001769417 0.0004436599
# 9   0.0001769417 0.0004436599
# 10  0.0001769417 0.0004436599
# 11  0.0001769417 0.0004436599
# 12  0.0001769417 0.0004436599
# 13  0.0001769417 0.0004436599
# 14  0.0001769417 0.0004436599
# 15  0.0001769417 0.0004436599
# 16  0.0001769417 0.0004436599
# 17  0.0001769417 0.0004436599
# 18  0.0001769417 0.0004436599
# 19  0.0001769417 0.0004436599
# 20  0.0001769417 0.0004436599
# 21  0.0001769417 0.0004436599
# 22  0.0001769417 0.0004436599
# 23  0.0001769417 0.0004436599
# 24  0.0001769417 0.0004436599
# 25  0.0001769417 0.0004436599
# 26  0.0001769417 0.0004436599
# 27  0.0001769417 0.0004436599
# 28  0.0001661424 0.0013138499
# 29  0.0001661424 0.0013138499
# 30  0.0001661424 0.0013138499
# ⋮   ⋮            ⋮
# 79  0.0001304010 0.0004552872
# 80  0.0001304010 0.0004552872
# 81  0.0001304010 0.0004552872
# 82  0.0005776965 0.0008233748
# 83  0.0005776965 0.0008233748
# 84  0.0005776965 0.0008233748
# 85  0.0005776965 0.0008233748
# 86  0.0005776965 0.0008233748
# 87  0.0005776965 0.0008233748
# 88  0.0005776965 0.0008233748
# 89  0.0005776965 0.0008233748
# 90  0.0005776965 0.0008233748
# 91  0.0005776965 0.0008233748
# 92  0.0005776965 0.0008233748
# 93  0.0005776965 0.0008233748
# 94  0.0005776965 0.0008233748
# 95  0.0005776965 0.0008233748
# 96  0.0005776965 0.0008233748
# 97  0.0005776965 0.0008233748
# 98  0.0005776965 0.0008233748
# 99  0.0005776965 0.0008233748
# 100 0.0005776965 0.0008233748
# 101 0.0005776965 0.0008233748
# 102 0.0005776965 0.0008233748
# 103 0.0005776965 0.0008233748
# 104 0.0005776965 0.0008233748
# 105 0.0005776965 0.0008233748
# 106 0.0005776965 0.0008233748
# 107 0.0005776965 0.0008233748
# 108 0.0005776965 0.0008233748

# %%
tissue_performance[,.(num_tissues=.N, median_auc=median(`auc`)), by="model"][order(`median_auc`)]
# Out:
#   model              num_tissues median_auc
# 1 AbExp\n+ Aparent2  27          0.0001304010
# 2 AbExp\n+ SpeciesLM 27          0.0001661424
# 3 AbExp              27          0.0001769417
# 4 AbExp\n+ Enformer  27          0.0005776965

# %%
auc_df = unique(prc_df[, .(`model`, `auc`, `idx`)])
auc_df[order(`auc`)]
# Out:
#   model              auc          idx
# 1 AbExp\n+ Aparent2  0.0001271040 2
# 2 AbExp\n+ SpeciesLM 0.0001504100 1
# 3 AbExp              0.0001611980 0
# 4 AbExp\n+ Enformer  0.0005235537 3

# %%
options(repr.plot.width=15, repr.plot.height=8)

# %%
auc_bar_plot = (
    ggplot(auc_df, aes(x=reorder(`model`, `auc`), y=`auc`, fill=`model`))
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_bar(stat="identity")
    + scale_y_continuous(labels = scales::percent)
    # + scale_x_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + xlim(-0.05, 1.05)
    # + ylim(-0.05, 1.05)
    + xlab("")
    + THEME
    + background_grid()
    + coord_flip()
)
auc_bar_plot
# Out:
# plot without title

# %%
# tissue_performance = tissue_performance %>% mutate(model = reorder(`model`, `auc`, FUN = median))

# %%
comparisons = list(
    # Comparisons against the baseline AbExp
    # c('AbExp', 'AbExp\n+ TSS'),
    # c('AbExp', 'AbExp\n+ PAS'),
    # c('AbExp', 'AbExp\n+ PAS + TSS'),
    c('AbExp', 'AbExp\n+ Enformer'),
    c('AbExp', 'AbExp\n+ Aparent2'),
    c('AbExp', 'AbExp\n+ SpeciesLM'),
    # compare tss and pas annotations against the models
    # c('AbExp\n+ TSS', 'AbExp\n+ Enformer'),
    # c('AbExp\n+ TSS', 'AbExp\n+ Aparent2'),
    # c('AbExp\n+ TSS', 'AbExp\n+ SpeciesLM'),
    # # compare the models with each other
    c('AbExp\n+ Enformer', 'AbExp\n+ SpeciesLM'),
    c('AbExp\n+ Aparent2', 'AbExp\n+ SpeciesLM')
)

# %%
stat.test <- (
    tissue_performance
    %>% wilcox_test(`auc` ~ `model`, paired=TRUE, comparisons = comparisons, alternative='less') 
    %>% add_significance("p")
)


# Add p-values to a boxplot
stat.test <- stat.test %>% add_xy_position(x = "model")
stat.test$all_lower = apply(stat.test, 1, function(x) all_lower(tissue_performance, "model", "auc", x$`group2`, x$`group1`) | all_lower(tissue_performance, "model", "auc", x$`group1`, x$`group2`))
stat.test$p_label = paste0(ifelse(stat.test$all_lower, "P < ", "P = "), lapply(stat.test$p, function(x) fancy_scientific(x, 3)))
as.data.table(stat.test)
# Out:
#   .y. group1             group2             n1 n2 statistic p        p.adj
# 1 auc AbExp              AbExp\n+ Enformer  27 27  65       0.001000 0.005
# 2 auc AbExp              AbExp\n+ Aparent2  27 27 289       0.993000 1.000
# 3 auc AbExp              AbExp\n+ SpeciesLM 27 27 194       0.552000 1.000
# 4 auc AbExp\n+ SpeciesLM AbExp\n+ Enformer  27 27  65       0.001000 0.005
# 5 auc AbExp\n+ Aparent2  AbExp\n+ SpeciesLM 27 27  64       0.000929 0.005
#   p.adj.signif p.signif y.position groups                                 xmin
# 1 **           ***      0.00760    AbExp            , AbExp\n+ Enformer   1
# 2 ns           ns       0.00835    AbExp            , AbExp\n+ Aparent2   1
# 3 ns           ns       0.00910    AbExp             , AbExp\n+ SpeciesLM 1
# 4 **           ***      0.00985    AbExp\n+ Enformer , AbExp\n+ SpeciesLM 3
# 5 **           ***      0.01060    AbExp\n+ Aparent2 , AbExp\n+ SpeciesLM 2
#   xmax all_lower p_label
# 1 4    FALSE     P = 1x10⁻³
# 2 2    FALSE     P = 0.993
# 3 3    FALSE     P = 0.552
# 4 4    FALSE     P = 1x10⁻³
# 5 3    FALSE     P = 9.29x10⁻⁴

# %%
seq(from=0.03,by=0.001, length.out=length(comparisons))
# Out:
# [1] 0.030 0.031 0.032 0.033 0.034

# %%
stat.test$y.position = seq(from=0.003,by=0.001, length.out=length(comparisons))
# stat.test$y.position = c(0.19, 0.15, 0.17, 0.21, 
#                          0.23, 0.25, 
#                          0.27, 0.31, 0.29)

# %%
options(repr.plot.width=4, repr.plot.height=4, repr.plot.res=300)
auc_plot <- (
    ggplot(tissue_performance, aes(y=`auc`, x=`model`))
    # + scale_fill_manual(values=color_list)
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_boxplot(aes(fill=`model`))
    + scale_y_continuous(
        limits=c(0, max(tissue_performance$auc) * 1.1),
        labels=scales::percent
    )
    # + scale_y_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + geom_jitter(alpha=0.5)
    + THEME
    + background_grid(major = "xy")
    # + theme(legend.title = element_blank(), axis.title.y=element_blank())
    + theme(legend.title = element_blank())
    + theme(legend.position = "none")
    + coord_flip()
    + labs(
        y="AUPRC",
        x=element_blank(),
        title="Across tissues"
    )
    + stat_pvalue_manual(stat.test, label = "{p_label}", coord.flip=TRUE)
    # + stat_compare_means(
    #     comparisons = list(
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "LOFTEE"),
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "CADD")
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP"]], rename_models[["LOFTEE+CADD+VEP"]])
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP+dispersion"]], rename_models[["LOFTEE+CADD+weighted VEP"]])
    #         # c("AbExp-DNA:\nvariant effects + tissue-specificity + AbSplice + SV", "variant effects + tissue-specificity + AbSplice")
    #     ),
    #     method = "wilcox.test",
    #     paired=TRUE,
    # )
)
auc_plot
# Out:
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# plot without title

# %%
width=4
height=4

path = paste(output_path, 'single_auc_over', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), auc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_auc_over..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”

# %%
options(repr.plot.width=3, repr.plot.height=4, repr.plot.res=300)
prc_plot = (
    ggplot(prc_df, aes(x=`recall`, y=`precision`))
    + geom_step(aes(color=reorder(`model`, `idx`)), linewidth=LINESIZE, direction="vh")
    # + scale_color_manual(name = element_blank(), values=nonbinary_model_colors)
    # + new_scale("color")
    + THEME
+ scale_x_continuous(
        limits = c(0, 1),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + scale_y_continuous(
        limits = c(0, 1),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + coord_cartesian(xlim=c(0,0.015), ylim = c(0, 0.5))
    + scale_shape_manual(name=element_blank(), values=c(4, 4))
    + guides(color=guide_legend(order = 1), shape=guide_legend(order = 2))
    + theme(
        #legend.position="right",
        legend.title=element_blank(),
        legend.position = c(0.95, 0.95),
        legend.justification = c("right", "top"),
        legend.key.height = unit(1, "cm")
        # axis.text.x=element_text(angle=45, hjust=1),
    )
    + labs(
        x='Recall',
        y='Precision',
        title="All tissues"
    )
)
prc_plot
# Out:
# Warning message:
# “A numeric `legend.position` argument in `theme()` was deprecated in ggplot2
# 3.5.0.
# ℹ Please use the `legend.position.inside` argument of `theme()` instead.”
# plot without title

# %%
width=7
height=4

path = paste(output_path, 'single_prc_over', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), prc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_prc_over..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”

# %%
options(repr.plot.width=8, repr.plot.height=4, repr.plot.res=300)
p <- plot_grid(auc_plot, prc_plot, rel_widths = c(5, 3))
p
# Out:
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 9.29x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# plot without title

# %%
width=8
height=4

path = paste(output_path, 'single_prc_auc_over', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), p, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_prc_auc_over..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”

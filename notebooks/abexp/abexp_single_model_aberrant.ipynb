# %%
library(IRdisplay)
library(Cairo)

library(data.table)
library(arrow)
library(ggplot2)
library(cowplot)
library(ggrepel)
library(ggthemes)
library(ggpubr)
library(ggtext)
library(patchwork)
library(grid)
library(gridExtra)
library(scales)
library(stringr)
library(RColorBrewer)
library(yaml)
library(plyr)
# library(dplyr)
library(tidyverse)
library(ggnewscale)
library(png)
library(rstatix)
# Out:
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘ggthemes’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     theme_map
#
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
#
# Attaching package: ‘plyr’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     mutate
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()      masks plyr::arrange()
# ✖ dplyr::between()      masks data.table::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ dplyr::combine()      masks gridExtra::combine()
# ✖ purrr::compact()      masks plyr::compact()
# ✖ dplyr::count()        masks plyr::count()
# ✖ dplyr::desc()         masks plyr::desc()
# ✖ purrr::discard()      masks scales::discard()
# ✖ lubridate::duration() masks arrow::duration()
# ✖ dplyr::failwith()     masks plyr::failwith()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ dplyr::first()        masks data.table::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ dplyr::id()           masks plyr::id()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ dplyr::last()         masks data.table::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ dplyr::mutate()       masks plyr::mutate(), ggpubr::mutate()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ dplyr::rename()       masks plyr::rename()
# ✖ lubridate::second()   masks data.table::second()
# ✖ lubridate::stamp()    masks cowplot::stamp()
# ✖ dplyr::summarise()    masks plyr::summarise()
# ✖ dplyr::summarize()    masks plyr::summarize()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘rstatix’
#
#
# The following objects are masked from ‘package:plyr’:
#
#     desc, mutate
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
LINESIZE = .3
FONTSIZE = 12
THEME = theme_cowplot(font_size = FONTSIZE, font_family = 'Helvetica') + theme(plot.tag = element_text(face = "bold"))

# %%
output_path = '/data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots'

# %%
base_path <- '/data/nasif12/home_if12/tsi/training_results_v16/gtex_v8_old_dna/predict_folds/subset=all/plots/compare_results.py@dna_only_splice_sv_dups_Enformer_Aparent2_SpeciesLM/aberrant_expression'

# %%
# %%
superscript_mapping = c(
    `-` = '⁻',
    `+` = "", # ⁺
    `0` = "\u2070",
    `1` = "\u00B9",
    `2` = "\u00B2",
    `3` = "\u00B3",
    `4` = "\u2074",
    `5` = "\u2075",
    `6` = "\u2076",
    `7` = "\u2077",
    `8` = "\u2078",
    `9` = "\u2079"
)

# %%
fancy_scientific <- function(l, digits=NULL, low=1/1000, high=1000) {
    # turn in to character string in scientific notation
    l = as.numeric(l)
    if (is.na(l)) {
        return("NA")
    }
    if (l == 0) {
        return("0")
    }
    if ((low < l) & (l < high)){
        return(format(l, scientific=FALSE, digits=digits, big.mark=",", trim=TRUE))
    }
    l = format(l, scientific=TRUE, digits=digits)

    # l <- format(l, scientific = TRUE)
    # split into factor and exponent
    l_split = strsplit(l, 'e')[[1]]
    if (! is.null(digits)) {
        l_split[1] = round(as.numeric(l_split[1]), digits)
    }
    # make exponent superscript
    l_split[2] = as.numeric(l_split[2])
    l_split[2] = paste(
        lapply(strsplit(l_split[2], "")[[1]], function(x) noquote(superscript_mapping[[x]])),
        collapse=''
    )
    # concat everything
    l_split = paste0(l_split[1], "x10", l_split[2])

    l_split
}

# %%
all_lower = function(df, model_col, value_col, comp_x, comp_y){
    val_x = df[[value_col]][df[[model_col]] == comp_x]
    val_y = df[[value_col]][df[[model_col]] == comp_y]
    return(all(val_x < val_y))
}

# %%
selected_models = c(
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM"
)
selected_models
# Out:
# [1] "LOFTEE+CADD+weighted csq.+disp.+AbSplice"
# [2] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss"
# [3] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer"
# [4] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2"
# [5] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM"

# %%
rename_models = list(
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice` = 'AbExp',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss` = 'AbExp\n+ TSS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas` = 'AbExp\n+ PAS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss` = 'AbExp\n+ PAS + TSS',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer` = 'AbExp\n+ Enformer',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2` = 'AbExp\n+ Aparent2',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM` = 'AbExp\n+ SpeciesLM'
)

# %%
# sapply(comparisons, function(x) x[1] %in% rename_models & x[2] %in% rename_models )

# %%
# rename_models = as.list(selected_models)
# names(rename_models) = rename_models

# %%
rename_models
# Out:
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice`
# [1] "AbExp"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss`
# [1] "AbExp\n+ TSS"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer`
# [1] "AbExp\n+ Enformer"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2`
# [1] "AbExp\n+ Aparent2"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM`
# [1] "AbExp\n+ SpeciesLM"

# %%
prc_df = as.data.table(read_parquet(file.path(base_path, "/prc_df.parquet")))
prc_df = prc_df[`model` %in% selected_models]
model_idx = unique(prc_df[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
prc_df$model <- factor(prc_df$model, levels=model_idx$model)
prc_df$model <- recode(prc_df$model, !!!rename_models)
prc_df
# Out:
#       precision recall threshold    is_binary auc        model
# 1     0.0000    0e+00  6.530971     FALSE     0.03237038 AbExp
# 2     0.2500    0e+00  6.479377     FALSE     0.03237038 AbExp
# 3     0.4000    1e-04  6.475304     FALSE     0.03237038 AbExp
# 4     0.5000    1e-04  6.448271     FALSE     0.03237038 AbExp
# 5     0.5000    2e-04  6.447859     FALSE     0.03237038 AbExp
# 6     0.4444    2e-04  6.323641     FALSE     0.03237038 AbExp
# 7     0.5000    2e-04  6.288099     FALSE     0.03237038 AbExp
# 8     0.5385    3e-04  6.103118     FALSE     0.03237038 AbExp
# 9     0.5714    3e-04  6.020144     FALSE     0.03237038 AbExp
# 10    0.5333    3e-04  5.989105     FALSE     0.03237038 AbExp
# 11    0.5625    4e-04  5.961565     FALSE     0.03237038 AbExp
# 12    0.5294    4e-04  5.939749     FALSE     0.03237038 AbExp
# 13    0.4737    4e-04  5.908356     FALSE     0.03237038 AbExp
# 14    0.4500    4e-04  5.869215     FALSE     0.03237038 AbExp
# 15    0.4286    4e-04  5.810827     FALSE     0.03237038 AbExp
# 16    0.4091    4e-04  5.810391     FALSE     0.03237038 AbExp
# 17    0.3913    4e-04  5.804292     FALSE     0.03237038 AbExp
# 18    0.3750    4e-04  5.797626     FALSE     0.03237038 AbExp
# 19    0.3600    4e-04  5.773892     FALSE     0.03237038 AbExp
# 20    0.3846    4e-04  5.746597     FALSE     0.03237038 AbExp
# 21    0.4074    4e-04  5.744756     FALSE     0.03237038 AbExp
# 22    0.3929    4e-04  5.716573     FALSE     0.03237038 AbExp
# 23    0.4138    5e-04  5.699363     FALSE     0.03237038 AbExp
# 24    0.4000    5e-04  5.676383     FALSE     0.03237038 AbExp
# 25    0.4194    5e-04  5.653390     FALSE     0.03237038 AbExp
# 26    0.4062    5e-04  5.641678     FALSE     0.03237038 AbExp
# 27    0.4118    5e-04  5.636892     FALSE     0.03237038 AbExp
# 28    0.4286    6e-04  5.631460     FALSE     0.03237038 AbExp
# 29    0.3846    6e-04  5.603445     FALSE     0.03237038 AbExp
# 30    0.3750    6e-04  5.603344     FALSE     0.03237038 AbExp
# ⋮     ⋮         ⋮      ⋮            ⋮         ⋮          ⋮
# 48497 3e-04     0.9899 2.639790e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48498 3e-04     0.9906 2.638331e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48499 3e-04     0.9907 2.612180e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48500 3e-04     0.9908 2.563172e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48501 3e-04     0.9909 2.544306e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48502 3e-04     0.9910 2.435385e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48503 3e-04     0.9928 2.108679e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48504 3e-04     0.9929 1.937141e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48505 3e-04     0.9937 1.895806e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48506 3e-04     0.9938 1.817246e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48507 3e-04     0.9945 1.775085e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48508 3e-04     0.9948 1.755457e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48509 3e-04     0.9956 1.732108e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48510 3e-04     0.9957 1.636772e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48511 3e-04     0.9958 1.598415e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48512 3e-04     0.9970 1.402492e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48513 3e-04     0.9973 1.334359e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48514 3e-04     0.9974 1.276153e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48515 3e-04     0.9976 1.115971e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48516 3e-04     0.9977 1.107426e-04 FALSE     0.03333631 AbExp\n+ TSS
# 48517 3e-04     0.9978 8.524925e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48518 3e-04     0.9980 8.040696e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48519 3e-04     0.9981 6.860983e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48520 3e-04     0.9985 5.992436e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48521 3e-04     0.9986 5.366770e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48522 3e-04     0.9991 4.339686e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48523 3e-04     0.9995 2.232886e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48524 3e-04     0.9998 1.000341e-05 FALSE     0.03333631 AbExp\n+ TSS
# 48525 3e-04     0.9999 6.278816e-06 FALSE     0.03333631 AbExp\n+ TSS
# 48526 3e-04     1.0000 2.822276e-06 FALSE     0.03333631 AbExp\n+ TSS
#       label                                                            idx
# 1     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 2     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 3     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 4     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 5     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 6     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 7     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 8     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 9     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 10    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 11    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 12    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 13    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 14    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 15    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 16    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 17    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 18    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 19    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 20    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 21    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 22    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 23    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 24    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 25    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 26    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 27    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 28    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 29    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# 30    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(3.24% auPRC)          0
# ⋮     ⋮                                                                ⋮
# 48497 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48498 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48499 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48500 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48501 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48502 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48503 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48504 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48505 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48506 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48507 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48508 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48509 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48510 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48511 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48512 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48513 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48514 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48515 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48516 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48517 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48518 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48519 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48520 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48521 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48522 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48523 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48524 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48525 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7
# 48526 LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss\n(3.33% auPRC) 7

# %%
tissue_performance = as.data.table(read_parquet(file.path(base_path, "/performance.tissue.parquet")))
tissue_performance = tissue_performance[`model` %in% selected_models]
model_idx = unique(tissue_performance[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
tissue_performance$model <- factor(tissue_performance$model, levels=model_idx$model)
tissue_performance$model <- recode(tissue_performance$model, !!!rename_models)
tissue_performance
# Out:
#     model              tissue          auc          idx n_true auc_mean
# 1   AbExp              Adipose Tissue  0.0296261852 0   1898   0.02421933
# 2   AbExp              Adrenal Gland   0.0304104547 0    396   0.02421933
# 3   AbExp              Blood           0.0200048850 0   1178   0.02421933
# 4   AbExp              Blood Vessel    0.0457655088 0   2038   0.02421933
# 5   AbExp              Brain           0.0317496628 0   3439   0.02421933
# 6   AbExp              Breast          0.0155900235 0    631   0.02421933
# 7   AbExp              Colon           0.0230549496 0   1117   0.02421933
# 8   AbExp              Esophagus       0.0392731292 0   2287   0.02421933
# 9   AbExp              Heart           0.0533124311 0   1094   0.02421933
# 10  AbExp              Kidney          0.0208735932 0     12   0.02421933
# 11  AbExp              Liver           0.0062135797 0    142   0.02421933
# 12  AbExp              Lung            0.0292855584 0    946   0.02421933
# 13  AbExp              Muscle          0.0512966280 0   1202   0.02421933
# 14  AbExp              Nerve           0.0260833415 0   1148   0.02421933
# 15  AbExp              Ovary           0.0074967233 0    163   0.02421933
# 16  AbExp              Pancreas        0.0287024037 0    401   0.02421933
# 17  AbExp              Pituitary       0.0077292097 0    473   0.02421933
# 18  AbExp              Prostate        0.0042807483 0    258   0.02421933
# 19  AbExp              Salivary Gland  0.0119857701 0    163   0.02421933
# 20  AbExp              Skin            0.0570813097 0   3619   0.02421933
# 21  AbExp              Small Intestine 0.0076123034 0    210   0.02421933
# 22  AbExp              Spleen          0.0137862728 0    306   0.02421933
# 23  AbExp              Stomach         0.0183570817 0    439   0.02421933
# 24  AbExp              Testis          0.0351511113 0    630   0.02421933
# 25  AbExp              Thyroid         0.0264644778 0   1266   0.02421933
# 26  AbExp              Uterus          0.0120314418 0     93   0.02421933
# 27  AbExp              Vagina          0.0007031685 0    115   0.02421933
# 28  AbExp\n+ SpeciesLM Adipose Tissue  0.0308719486 1   1898   0.02589444
# 29  AbExp\n+ SpeciesLM Adrenal Gland   0.0306814811 1    396   0.02589444
# 30  AbExp\n+ SpeciesLM Blood           0.0209217198 1   1178   0.02589444
# ⋮   ⋮                  ⋮               ⋮            ⋮   ⋮      ⋮
# 106 AbExp\n+ Enformer  Thyroid         0.0296829817 3   1266   0.02525754
# 107 AbExp\n+ Enformer  Uterus          0.0079664729 3     93   0.02525754
# 108 AbExp\n+ Enformer  Vagina          0.0009537211 3    115   0.02525754
# 109 AbExp\n+ TSS       Adipose Tissue  0.0304531522 7   1898   0.02489702
# 110 AbExp\n+ TSS       Adrenal Gland   0.0314152586 7    396   0.02489702
# 111 AbExp\n+ TSS       Blood           0.0199482365 7   1178   0.02489702
# 112 AbExp\n+ TSS       Blood Vessel    0.0474233931 7   2038   0.02489702
# 113 AbExp\n+ TSS       Brain           0.0321644238 7   3439   0.02489702
# 114 AbExp\n+ TSS       Breast          0.0178298819 7    631   0.02489702
# 115 AbExp\n+ TSS       Colon           0.0240592237 7   1117   0.02489702
# 116 AbExp\n+ TSS       Esophagus       0.0401919377 7   2287   0.02489702
# 117 AbExp\n+ TSS       Heart           0.0539850835 7   1094   0.02489702
# 118 AbExp\n+ TSS       Kidney          0.0208779522 7     12   0.02489702
# 119 AbExp\n+ TSS       Liver           0.0096351067 7    142   0.02489702
# 120 AbExp\n+ TSS       Lung            0.0287655443 7    946   0.02489702
# 121 AbExp\n+ TSS       Muscle          0.0535331217 7   1202   0.02489702
# 122 AbExp\n+ TSS       Nerve           0.0266880437 7   1148   0.02489702
# 123 AbExp\n+ TSS       Ovary           0.0078280555 7    163   0.02489702
# 124 AbExp\n+ TSS       Pancreas        0.0300039061 7    401   0.02489702
# 125 AbExp\n+ TSS       Pituitary       0.0078832591 7    473   0.02489702
# 126 AbExp\n+ TSS       Prostate        0.0051588238 7    258   0.02489702
# 127 AbExp\n+ TSS       Salivary Gland  0.0131775953 7    163   0.02489702
# 128 AbExp\n+ TSS       Skin            0.0590035272 7   3619   0.02489702
# 129 AbExp\n+ TSS       Small Intestine 0.0079945393 7    210   0.02489702
# 130 AbExp\n+ TSS       Spleen          0.0132753192 7    306   0.02489702
# 131 AbExp\n+ TSS       Stomach         0.0201427509 7    439   0.02489702
# 132 AbExp\n+ TSS       Testis          0.0333926764 7    630   0.02489702
# 133 AbExp\n+ TSS       Thyroid         0.0277036702 7   1266   0.02489702
# 134 AbExp\n+ TSS       Uterus          0.0089016235 7     93   0.02489702
# 135 AbExp\n+ TSS       Vagina          0.0007833946 7    115   0.02489702
#     auc_median auc_std
# 1   0.02305495 0.01556219
# 2   0.02305495 0.01556219
# 3   0.02305495 0.01556219
# 4   0.02305495 0.01556219
# 5   0.02305495 0.01556219
# 6   0.02305495 0.01556219
# 7   0.02305495 0.01556219
# 8   0.02305495 0.01556219
# 9   0.02305495 0.01556219
# 10  0.02305495 0.01556219
# 11  0.02305495 0.01556219
# 12  0.02305495 0.01556219
# 13  0.02305495 0.01556219
# 14  0.02305495 0.01556219
# 15  0.02305495 0.01556219
# 16  0.02305495 0.01556219
# 17  0.02305495 0.01556219
# 18  0.02305495 0.01556219
# 19  0.02305495 0.01556219
# 20  0.02305495 0.01556219
# 21  0.02305495 0.01556219
# 22  0.02305495 0.01556219
# 23  0.02305495 0.01556219
# 24  0.02305495 0.01556219
# 25  0.02305495 0.01556219
# 26  0.02305495 0.01556219
# 27  0.02305495 0.01556219
# 28  0.02781846 0.01568776
# 29  0.02781846 0.01568776
# 30  0.02781846 0.01568776
# ⋮   ⋮          ⋮
# 106 0.02487223 0.01543542
# 107 0.02487223 0.01543542
# 108 0.02487223 0.01543542
# 109 0.02405922 0.01585257
# 110 0.02405922 0.01585257
# 111 0.02405922 0.01585257
# 112 0.02405922 0.01585257
# 113 0.02405922 0.01585257
# 114 0.02405922 0.01585257
# 115 0.02405922 0.01585257
# 116 0.02405922 0.01585257
# 117 0.02405922 0.01585257
# 118 0.02405922 0.01585257
# 119 0.02405922 0.01585257
# 120 0.02405922 0.01585257
# 121 0.02405922 0.01585257
# 122 0.02405922 0.01585257
# 123 0.02405922 0.01585257
# 124 0.02405922 0.01585257
# 125 0.02405922 0.01585257
# 126 0.02405922 0.01585257
# 127 0.02405922 0.01585257
# 128 0.02405922 0.01585257
# 129 0.02405922 0.01585257
# 130 0.02405922 0.01585257
# 131 0.02405922 0.01585257
# 132 0.02405922 0.01585257
# 133 0.02405922 0.01585257
# 134 0.02405922 0.01585257
# 135 0.02405922 0.01585257

# %%
tissue_performance[,.(num_tissues=.N, median_auc=median(`auc`)), by="model"][order(`median_auc`)]
# Out:
#   model              num_tissues median_auc
# 1 AbExp              27          0.02305495
# 2 AbExp\n+ TSS       27          0.02405922
# 3 AbExp\n+ Enformer  27          0.02487223
# 4 AbExp\n+ Aparent2  27          0.02549543
# 5 AbExp\n+ SpeciesLM 27          0.02781846

# %%
auc_df = unique(prc_df[, .(`model`, `auc`, `idx`)])
auc_df[order(`auc`)]
# Out:
#   model              auc        idx
# 1 AbExp              0.03237038 0
# 2 AbExp\n+ Enformer  0.03326537 3
# 3 AbExp\n+ TSS       0.03333631 7
# 4 AbExp\n+ Aparent2  0.03346119 2
# 5 AbExp\n+ SpeciesLM 0.03396679 1

# %%
options(repr.plot.width=15, repr.plot.height=8)

# %%
auc_bar_plot = (
    ggplot(auc_df, aes(x=reorder(`model`, `auc`), y=`auc`, fill=`model`))
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_bar(stat="identity")
    + scale_y_continuous(labels = scales::percent)
    # + scale_x_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + xlim(-0.05, 1.05)
    # + ylim(-0.05, 1.05)
    + xlab("")
    + THEME
    + background_grid()
    + coord_flip()
)
auc_bar_plot
# Out:
# plot without title

# %%
tissue_performance = tissue_performance %>% mutate(model = reorder(`model`, `auc`, FUN = median))

# %%
comparisons = list(
    # Comparisons against the baseline AbExp
    c('AbExp', 'AbExp\n+ TSS'),
    # c('AbExp', 'AbExp\n+ PAS'),
    # c('AbExp', 'AbExp\n+ PAS + TSS'),
    c('AbExp', 'AbExp\n+ Enformer'),
    c('AbExp', 'AbExp\n+ Aparent2'),
    c('AbExp', 'AbExp\n+ SpeciesLM'),
    # compare tss and pas annotations against the models
    c('AbExp\n+ TSS', 'AbExp\n+ Enformer'),
    c('AbExp\n+ TSS', 'AbExp\n+ Aparent2'),
    c('AbExp\n+ TSS', 'AbExp\n+ SpeciesLM'),
    # # compare the models with each other
    c('AbExp\n+ Enformer', 'AbExp\n+ SpeciesLM'),
    c('AbExp\n+ Aparent2', 'AbExp\n+ SpeciesLM')
)

# %%
stat.test <- (
    tissue_performance
    %>% wilcox_test(`auc` ~ `model`, paired=TRUE, comparisons = comparisons, alternative='two.sided') 
    %>% add_significance("p")
)


# Add p-values to a boxplot
stat.test <- stat.test %>% add_xy_position(x = "model")
stat.test$all_lower = apply(stat.test, 1, function(x) all_lower(tissue_performance, "model", "auc", x$`group2`, x$`group1`) | all_lower(tissue_performance, "model", "auc", x$`group1`, x$`group2`))
stat.test$p_label = paste0(ifelse(stat.test$all_lower, "P < ", "P = "), lapply(stat.test$p, function(x) fancy_scientific(x, 3)))
as.data.table(stat.test)
# Out:
#   .y. group1            group2             n1 n2 statistic p        p.adj
# 1 auc AbExp             AbExp\n+ TSS       27 27  66       0.002000 0.013
# 2 auc AbExp             AbExp\n+ Enformer  27 27  59       0.001000 0.008
# 3 auc AbExp             AbExp\n+ Aparent2  27 27  55       0.000744 0.006
# 4 auc AbExp             AbExp\n+ SpeciesLM 27 27  40       0.000125 0.001
# 5 auc AbExp\n+ TSS      AbExp\n+ Enformer  27 27 141       0.258000 0.516
# 6 auc AbExp\n+ TSS      AbExp\n+ Aparent2  27 27 127       0.141000 0.423
# 7 auc AbExp\n+ TSS      AbExp\n+ SpeciesLM 27 27  74       0.005000 0.023
# 8 auc AbExp\n+ Enformer AbExp\n+ SpeciesLM 27 27 112       0.066000 0.262
# 9 auc AbExp\n+ Aparent2 AbExp\n+ SpeciesLM 27 27 161       0.515000 0.516
#   p.adj.signif p.signif y.position groups                                 xmin
# 1 *            **       0.060360   AbExp       , AbExp\n+ TSS             1
# 2 **           ***      0.060765   AbExp            , AbExp\n+ Enformer   1
# 3 **           ***      0.061170   AbExp            , AbExp\n+ Aparent2   1
# 4 **           ***      0.061575   AbExp             , AbExp\n+ SpeciesLM 1
# 5 ns           ns       0.061980   AbExp\n+ TSS     , AbExp\n+ Enformer   2
# 6 ns           ns       0.062385   AbExp\n+ TSS     , AbExp\n+ Aparent2   2
# 7 *            **       0.062790   AbExp\n+ TSS      , AbExp\n+ SpeciesLM 2
# 8 ns           ns       0.063195   AbExp\n+ Enformer , AbExp\n+ SpeciesLM 3
# 9 ns           ns       0.063600   AbExp\n+ Aparent2 , AbExp\n+ SpeciesLM 4
#   xmax all_lower p_label
# 1 2    FALSE     P = 0.002
# 2 3    FALSE     P = 1x10⁻³
# 3 4    FALSE     P = 7.44x10⁻⁴
# 4 5    FALSE     P = 1.25x10⁻⁴
# 5 3    FALSE     P = 0.258
# 6 4    FALSE     P = 0.141
# 7 5    FALSE     P = 0.005
# 8 5    FALSE     P = 0.066
# 9 5    FALSE     P = 0.515

# %%
seq(from=0.15,by=0.02, length.out=length(comparisons))
# Out:
# [1] 0.15 0.17 0.19 0.21 0.23 0.25 0.27 0.29 0.31

# %%
stat.test$y.position = seq(from=0.06,by=0.008, length.out=length(comparisons))

# %%
options(repr.plot.width=7, repr.plot.height=4, repr.plot.res=300)
auc_plot <- (
    ggplot(tissue_performance, aes(y=`auc`, x=`model`))
    # + scale_fill_manual(values=color_list)
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_boxplot(aes(fill=`model`))
    + scale_y_continuous(
        limits=c(0, max(tissue_performance$auc) * 2),
        labels=scales::percent
    )
    # + scale_y_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + geom_jitter(alpha=0.5)
    + THEME
    + background_grid(major = "xy")
    # + theme(legend.title = element_blank(), axis.title.y=element_blank())
    + theme(legend.title = element_blank())
    + theme(legend.position = "none")
    + coord_flip()
    + labs(
        y="AUPRC",
        x=element_blank(),
        title="Across tissues"
    )
    + stat_pvalue_manual(stat.test, label = "{p_label}", coord.flip=TRUE)
    # + stat_compare_means(
    #     comparisons = list(
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "LOFTEE"),
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "CADD")
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP"]], rename_models[["LOFTEE+CADD+VEP"]])
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP+dispersion"]], rename_models[["LOFTEE+CADD+weighted VEP"]])
    #         # c("AbExp-DNA:\nvariant effects + tissue-specificity + AbSplice + SV", "variant effects + tissue-specificity + AbSplice")
    #     ),
    #     method = "wilcox.test",
    #     paired=TRUE,
    # )
)
auc_plot
# Out:
# Warning message:
# “Removed 1 row containing non-finite outside the scale range (`stat_bracket()`).”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1x10⁻³' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 7.44x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.25x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# plot without title

# %%
width=7
height=4

path = paste(output_path, 'single_auc_aberrant', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), auc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_auc_aberrant..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”
# Warning message:
# “Removed 1 row containing non-finite outside the scale range (`stat_bracket()`).”

# %%
options(repr.plot.width=6, repr.plot.height=4, repr.plot.res=300)
prc_plot = (
    ggplot(prc_df, aes(x=`recall`, y=`precision`))
    + geom_step(aes(color=reorder(`model`, `idx`)), linewidth=LINESIZE, direction="vh")
    # + scale_color_manual(name = element_blank(), values=nonbinary_model_colors)
    # + new_scale("color")
    + THEME
    + background_grid(major = "xy", minor = "xy")
    + scale_x_continuous(
        limits = c(0, 0.5),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + scale_y_continuous(
        limits = c(0, 1.05),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + scale_shape_manual(name=element_blank(), values=c(4, 4))
    + guides(color=guide_legend(order = 1), shape=guide_legend(order = 2))
    + theme(
        #legend.position="right",
        legend.title=element_blank(),
        legend.position = c(0.95, 0.95),
        legend.justification = c("right", "top"),
        legend.key.height = unit(1, "cm")
        # axis.text.x=element_text(angle=45, hjust=1),
    )
    + labs(
        x='Recall',
        y='Precision',
        title="All tissues"
    )
)
prc_plot
# Out:
# Warning message:
# “A numeric `legend.position` argument in `theme()` was deprecated in ggplot2
# 3.5.0.
# ℹ Please use the `legend.position.inside` argument of `theme()` instead.”
# Warning message:
# “Removed 2478 rows containing missing values or values outside the scale range
# (`geom_step()`).”
# plot without title

# %%
width=7
height=4

path = paste(output_path, 'single_prc_aberrant', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), prc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_prc_aberrant..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”
# Warning message:
# “Removed 2478 rows containing missing values or values outside the scale range
# (`geom_step()`).”

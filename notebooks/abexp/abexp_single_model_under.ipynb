# %%
library(IRdisplay)
library(Cairo)

library(data.table)
library(arrow)
library(ggplot2)
library(cowplot)
library(ggrepel)
library(ggthemes)
library(ggpubr)
library(ggtext)
library(patchwork)
library(grid)
library(gridExtra)
library(scales)
library(stringr)
library(RColorBrewer)
library(yaml)
library(plyr)
# library(dplyr)
library(tidyverse)
library(ggnewscale)
library(png)
library(rstatix)
# Out:
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
#
# Attaching package: ‘ggthemes’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     theme_map
#
#
#
# Attaching package: ‘ggpubr’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     get_legend
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots
#
#
#
# Attaching package: ‘plyr’
#
#
# The following object is masked from ‘package:ggpubr’:
#
#     mutate
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()      masks plyr::arrange()
# ✖ dplyr::between()      masks data.table::between()
# ✖ readr::col_factor()   masks scales::col_factor()
# ✖ dplyr::combine()      masks gridExtra::combine()
# ✖ purrr::compact()      masks plyr::compact()
# ✖ dplyr::count()        masks plyr::count()
# ✖ dplyr::desc()         masks plyr::desc()
# ✖ purrr::discard()      masks scales::discard()
# ✖ lubridate::duration() masks arrow::duration()
# ✖ dplyr::failwith()     masks plyr::failwith()
# ✖ dplyr::filter()       masks stats::filter()
# ✖ dplyr::first()        masks data.table::first()
# ✖ lubridate::hour()     masks data.table::hour()
# ✖ dplyr::id()           masks plyr::id()
# ✖ lubridate::isoweek()  masks data.table::isoweek()
# ✖ dplyr::lag()          masks stats::lag()
# ✖ dplyr::last()         masks data.table::last()
# ✖ lubridate::mday()     masks data.table::mday()
# ✖ lubridate::minute()   masks data.table::minute()
# ✖ lubridate::month()    masks data.table::month()
# ✖ dplyr::mutate()       masks plyr::mutate(), ggpubr::mutate()
# ✖ lubridate::quarter()  masks data.table::quarter()
# ✖ dplyr::rename()       masks plyr::rename()
# ✖ lubridate::second()   masks data.table::second()
# ✖ lubridate::stamp()    masks cowplot::stamp()
# ✖ dplyr::summarise()    masks plyr::summarise()
# ✖ dplyr::summarize()    masks plyr::summarize()
# ✖ purrr::transpose()    masks data.table::transpose()
# ✖ lubridate::wday()     masks data.table::wday()
# ✖ lubridate::week()     masks data.table::week()
# ✖ lubridate::yday()     masks data.table::yday()
# ✖ lubridate::year()     masks data.table::year()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘rstatix’
#
#
# The following objects are masked from ‘package:plyr’:
#
#     desc, mutate
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
LINESIZE = .3
FONTSIZE = 12
THEME = theme_cowplot(font_size = FONTSIZE, font_family = 'Helvetica') + theme(plot.tag = element_text(face = "bold"))

# %%
output_path = '/data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots'

# %%
base_path <- '/data/nasif12/home_if12/tsi/training_results_v16/gtex_v8_old_dna/predict_folds/subset=all/plots/compare_results.py@dna_only_splice_sv_dups_Enformer_Aparent2_SpeciesLM'

# %%
# %%
superscript_mapping = c(
    `-` = '⁻',
    `+` = "", # ⁺
    `0` = "\u2070",
    `1` = "\u00B9",
    `2` = "\u00B2",
    `3` = "\u00B3",
    `4` = "\u2074",
    `5` = "\u2075",
    `6` = "\u2076",
    `7` = "\u2077",
    `8` = "\u2078",
    `9` = "\u2079"
)

# %%
fancy_scientific <- function(l, digits=NULL, low=1/1000, high=1000) {
    # turn in to character string in scientific notation
    l = as.numeric(l)
    if (is.na(l)) {
        return("NA")
    }
    if (l == 0) {
        return("0")
    }
    if ((low < l) & (l < high)){
        return(format(l, scientific=FALSE, digits=digits, big.mark=",", trim=TRUE))
    }
    l = format(l, scientific=TRUE, digits=digits)

    # l <- format(l, scientific = TRUE)
    # split into factor and exponent
    l_split = strsplit(l, 'e')[[1]]
    if (! is.null(digits)) {
        l_split[1] = round(as.numeric(l_split[1]), digits)
    }
    # make exponent superscript
    l_split[2] = as.numeric(l_split[2])
    l_split[2] = paste(
        lapply(strsplit(l_split[2], "")[[1]], function(x) noquote(superscript_mapping[[x]])),
        collapse=''
    )
    # concat everything
    l_split = paste0(l_split[1], "x10", l_split[2])

    l_split
}

# %%
all_lower = function(df, model_col, value_col, comp_x, comp_y){
    val_x = df[[value_col]][df[[model_col]] == comp_x]
    val_y = df[[value_col]][df[[model_col]] == comp_y]
    return(all(val_x < val_y))
}

# %%
selected_models = c(
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas",
    # "LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2",
    "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM"
)
selected_models
# Out:
# [1] "LOFTEE+CADD+weighted csq.+disp.+AbSplice"
# [2] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer"
# [3] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2"
# [4] "LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM"

# %%
rename_models = list(
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice` = 'AbExp',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near tss` = 'AbExp\n+ TSS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas` = 'AbExp\n+ PAS',
    # `LOFTEE+CADD+weighted csq.+disp.+AbSplice+near pas+near tss` = 'AbExp\n+ PAS + TSS',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer` = 'AbExp\n+ Enformer',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2` = 'AbExp\n+ Aparent2',
    `LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM` = 'AbExp\n+ SpeciesLM'
)

# %%
# sapply(comparisons, function(x) x[1] %in% rename_models & x[2] %in% rename_models )

# %%
# rename_models = as.list(selected_models)
# names(rename_models) = rename_models

# %%
rename_models
# Out:
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice`
# [1] "AbExp"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer`
# [1] "AbExp\n+ Enformer"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+Aparent2`
# [1] "AbExp\n+ Aparent2"
#
# $`LOFTEE+CADD+weighted csq.+disp.+AbSplice+SpeciesLM`
# [1] "AbExp\n+ SpeciesLM"

# %%
prc_df = as.data.table(read_parquet(file.path(base_path, "/prc_df.parquet")))
prc_df = prc_df[`model` %in% selected_models]
model_idx = unique(prc_df[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
prc_df$model <- factor(prc_df$model, levels=model_idx$model)
prc_df$model <- recode(prc_df$model, !!!rename_models)
prc_df
# Out:
#       precision recall threshold  is_binary auc        model
# 1     0.0000    0.0000 6.530971   FALSE     0.06860093 AbExp
# 2     0.2500    0.0001 6.479377   FALSE     0.06860093 AbExp
# 3     0.4000    0.0002 6.475304   FALSE     0.06860093 AbExp
# 4     0.5000    0.0003 6.448271   FALSE     0.06860093 AbExp
# 5     0.5000    0.0004 6.447859   FALSE     0.06860093 AbExp
# 6     0.4444    0.0004 6.323641   FALSE     0.06860093 AbExp
# 7     0.5000    0.0004 6.288099   FALSE     0.06860093 AbExp
# 8     0.5000    0.0005 6.116747   FALSE     0.06860093 AbExp
# 9     0.5385    0.0006 6.103118   FALSE     0.06860093 AbExp
# 10    0.5714    0.0007 6.020144   FALSE     0.06860093 AbExp
# 11    0.5333    0.0007 5.989105   FALSE     0.06860093 AbExp
# 12    0.5625    0.0008 5.961565   FALSE     0.06860093 AbExp
# 13    0.5294    0.0008 5.939749   FALSE     0.06860093 AbExp
# 14    0.4737    0.0008 5.908356   FALSE     0.06860093 AbExp
# 15    0.4500    0.0008 5.869215   FALSE     0.06860093 AbExp
# 16    0.4286    0.0008 5.810827   FALSE     0.06860093 AbExp
# 17    0.4091    0.0008 5.810391   FALSE     0.06860093 AbExp
# 18    0.3913    0.0008 5.804292   FALSE     0.06860093 AbExp
# 19    0.3750    0.0008 5.797626   FALSE     0.06860093 AbExp
# 20    0.3600    0.0008 5.773892   FALSE     0.06860093 AbExp
# 21    0.3846    0.0009 5.746597   FALSE     0.06860093 AbExp
# 22    0.4074    0.0010 5.744756   FALSE     0.06860093 AbExp
# 23    0.3929    0.0010 5.716573   FALSE     0.06860093 AbExp
# 24    0.4138    0.0011 5.699363   FALSE     0.06860093 AbExp
# 25    0.4000    0.0011 5.676383   FALSE     0.06860093 AbExp
# 26    0.4194    0.0012 5.653390   FALSE     0.06860093 AbExp
# 27    0.4062    0.0012 5.641678   FALSE     0.06860093 AbExp
# 28    0.4118    0.0012 5.636892   FALSE     0.06860093 AbExp
# 29    0.4286    0.0013 5.631460   FALSE     0.06860093 AbExp
# 30    0.3846    0.0013 5.603445   FALSE     0.06860093 AbExp
# ⋮     ⋮         ⋮      ⋮          ⋮         ⋮          ⋮
# 38033 1e-04     0.9968 -0.1951474 FALSE     0.06990387 AbExp\n+ Enformer
# 38034 1e-04     0.9969 -0.2024937 FALSE     0.06990387 AbExp\n+ Enformer
# 38035 1e-04     0.9970 -0.2057665 FALSE     0.06990387 AbExp\n+ Enformer
# 38036 1e-04     0.9971 -0.2142974 FALSE     0.06990387 AbExp\n+ Enformer
# 38037 1e-04     0.9972 -0.2424999 FALSE     0.06990387 AbExp\n+ Enformer
# 38038 1e-04     0.9973 -0.2646129 FALSE     0.06990387 AbExp\n+ Enformer
# 38039 1e-04     0.9974 -0.2649073 FALSE     0.06990387 AbExp\n+ Enformer
# 38040 1e-04     0.9975 -0.2844427 FALSE     0.06990387 AbExp\n+ Enformer
# 38041 1e-04     0.9976 -0.2857258 FALSE     0.06990387 AbExp\n+ Enformer
# 38042 1e-04     0.9979 -0.2863967 FALSE     0.06990387 AbExp\n+ Enformer
# 38043 1e-04     0.9980 -0.3242849 FALSE     0.06990387 AbExp\n+ Enformer
# 38044 1e-04     0.9981 -0.3274382 FALSE     0.06990387 AbExp\n+ Enformer
# 38045 1e-04     0.9982 -0.3420788 FALSE     0.06990387 AbExp\n+ Enformer
# 38046 1e-04     0.9983 -0.3578808 FALSE     0.06990387 AbExp\n+ Enformer
# 38047 1e-04     0.9984 -0.3734364 FALSE     0.06990387 AbExp\n+ Enformer
# 38048 1e-04     0.9985 -0.3827042 FALSE     0.06990387 AbExp\n+ Enformer
# 38049 1e-04     0.9986 -0.4251931 FALSE     0.06990387 AbExp\n+ Enformer
# 38050 1e-04     0.9987 -0.4518865 FALSE     0.06990387 AbExp\n+ Enformer
# 38051 1e-04     0.9989 -0.4548214 FALSE     0.06990387 AbExp\n+ Enformer
# 38052 1e-04     0.9990 -0.4627010 FALSE     0.06990387 AbExp\n+ Enformer
# 38053 1e-04     0.9991 -0.4692801 FALSE     0.06990387 AbExp\n+ Enformer
# 38054 1e-04     0.9992 -0.5155387 FALSE     0.06990387 AbExp\n+ Enformer
# 38055 1e-04     0.9993 -0.5745911 FALSE     0.06990387 AbExp\n+ Enformer
# 38056 1e-04     0.9994 -0.5881881 FALSE     0.06990387 AbExp\n+ Enformer
# 38057 1e-04     0.9995 -0.5955053 FALSE     0.06990387 AbExp\n+ Enformer
# 38058 1e-04     0.9996 -0.6269841 FALSE     0.06990387 AbExp\n+ Enformer
# 38059 1e-04     0.9997 -0.6643367 FALSE     0.06990387 AbExp\n+ Enformer
# 38060 1e-04     0.9998 -0.6769057 FALSE     0.06990387 AbExp\n+ Enformer
# 38061 1e-04     0.9999 -0.6781736 FALSE     0.06990387 AbExp\n+ Enformer
# 38062 1e-04     1.0000 -0.7026437 FALSE     0.06990387 AbExp\n+ Enformer
#       label                                                            idx
# 1     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 2     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 3     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 4     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 5     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 6     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 7     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 8     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 9     LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 10    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 11    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 12    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 13    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 14    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 15    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 16    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 17    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 18    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 19    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 20    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 21    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 22    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 23    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 24    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 25    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 26    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 27    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 28    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 29    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# 30    LOFTEE+CADD+weighted csq.+disp.+AbSplice\n(6.86% auPRC)          0
# ⋮     ⋮                                                                ⋮
# 38033 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38034 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38035 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38036 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38037 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38038 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38039 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38040 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38041 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38042 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38043 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38044 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38045 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38046 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38047 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38048 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38049 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38050 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38051 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38052 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38053 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38054 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38055 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38056 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38057 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38058 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38059 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38060 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38061 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3
# 38062 LOFTEE+CADD+weighted csq.+disp.+AbSplice+Enformer\n(6.99% auPRC) 3

# %%
tissue_performance = as.data.table(read_parquet(file.path(base_path, "/performance.tissue.parquet")))
tissue_performance = tissue_performance[`model` %in% selected_models]
model_idx = unique(tissue_performance[,.(`model`, `idx`)])[order(`idx`, decreasing = FALSE)]
tissue_performance$model <- factor(tissue_performance$model, levels=selected_models)
tissue_performance$model <- recode(tissue_performance$model, !!!rename_models)
tissue_performance
# Out:
#     model              tissue          auc         idx n_true auc_mean
# 1   AbExp              Adipose Tissue  0.070079751 0    733   0.05527275
# 2   AbExp              Adrenal Gland   0.066544250 0    172   0.05527275
# 3   AbExp              Blood           0.037582248 0    591   0.05527275
# 4   AbExp              Blood Vessel    0.086945536 0    985   0.05527275
# 5   AbExp              Brain           0.073239027 0   1398   0.05527275
# 6   AbExp              Breast          0.043192488 0    205   0.05527275
# 7   AbExp              Colon           0.053932142 0    445   0.05527275
# 8   AbExp              Esophagus       0.077925204 0   1071   0.05527275
# 9   AbExp              Heart           0.105975515 0    522   0.05527275
# 10  AbExp              Kidney          0.125002600 0      2   0.05527275
# 11  AbExp              Liver           0.011935737 0     60   0.05527275
# 12  AbExp              Lung            0.072646399 0    354   0.05527275
# 13  AbExp              Muscle          0.111642978 0    532   0.05527275
# 14  AbExp              Nerve           0.058925089 0    462   0.05527275
# 15  AbExp              Ovary           0.014086167 0     58   0.05527275
# 16  AbExp              Pancreas        0.058331113 0    177   0.05527275
# 17  AbExp              Pituitary       0.024263298 0    123   0.05527275
# 18  AbExp              Prostate        0.012117069 0     75   0.05527275
# 19  AbExp              Salivary Gland  0.031988898 0     59   0.05527275
# 20  AbExp              Skin            0.096885261 0   2011   0.05527275
# 21  AbExp              Small Intestine 0.022255508 0     68   0.05527275
# 22  AbExp              Spleen          0.030056449 0    110   0.05527275
# 23  AbExp              Stomach         0.044946395 0    166   0.05527275
# 24  AbExp              Testis          0.070725329 0    291   0.05527275
# 25  AbExp              Thyroid         0.060576691 0    463   0.05527275
# 26  AbExp              Uterus          0.028563791 0     35   0.05527275
# 27  AbExp              Vagina          0.001999388 0     32   0.05527275
# 28  AbExp\n+ SpeciesLM Adipose Tissue  0.073381078 1    733   0.06041765
# 29  AbExp\n+ SpeciesLM Adrenal Gland   0.067163520 1    172   0.06041765
# 30  AbExp\n+ SpeciesLM Blood           0.039651601 1    591   0.06041765
# ⋮   ⋮                  ⋮               ⋮           ⋮   ⋮      ⋮
# 79  AbExp\n+ Aparent2  Thyroid         0.063037927 2    463   0.05897849
# 80  AbExp\n+ Aparent2  Uterus          0.034745532 2     35   0.05897849
# 81  AbExp\n+ Aparent2  Vagina          0.002780390 2     32   0.05897849
# 82  AbExp\n+ Enformer  Adipose Tissue  0.070303019 3    733   0.05516581
# 83  AbExp\n+ Enformer  Adrenal Gland   0.066684586 3    172   0.05516581
# 84  AbExp\n+ Enformer  Blood           0.036243200 3    591   0.05516581
# 85  AbExp\n+ Enformer  Blood Vessel    0.086122652 3    985   0.05516581
# 86  AbExp\n+ Enformer  Brain           0.074570956 3   1398   0.05516581
# 87  AbExp\n+ Enformer  Breast          0.046288569 3    205   0.05516581
# 88  AbExp\n+ Enformer  Colon           0.055021296 3    445   0.05516581
# 89  AbExp\n+ Enformer  Esophagus       0.079655094 3   1071   0.05516581
# 90  AbExp\n+ Enformer  Heart           0.103923092 3    522   0.05516581
# 91  AbExp\n+ Enformer  Kidney          0.100002637 3      2   0.05516581
# 92  AbExp\n+ Enformer  Liver           0.023337388 3     60   0.05516581
# 93  AbExp\n+ Enformer  Lung            0.067055274 3    354   0.05516581
# 94  AbExp\n+ Enformer  Muscle          0.110258161 3    532   0.05516581
# 95  AbExp\n+ Enformer  Nerve           0.058961364 3    462   0.05516581
# 96  AbExp\n+ Enformer  Ovary           0.015995041 3     58   0.05516581
# 97  AbExp\n+ Enformer  Pancreas        0.057044770 3    177   0.05516581
# 98  AbExp\n+ Enformer  Pituitary       0.025018683 3    123   0.05516581
# 99  AbExp\n+ Enformer  Prostate        0.014177401 3     75   0.05516581
# 100 AbExp\n+ Enformer  Salivary Gland  0.038310917 3     59   0.05516581
# 101 AbExp\n+ Enformer  Skin            0.100108294 3   2011   0.05516581
# 102 AbExp\n+ Enformer  Small Intestine 0.025691116 3     68   0.05516581
# 103 AbExp\n+ Enformer  Spleen          0.033398828 3    110   0.05516581
# 104 AbExp\n+ Enformer  Stomach         0.046851540 3    166   0.05516581
# 105 AbExp\n+ Enformer  Testis          0.064776365 3    291   0.05516581
# 106 AbExp\n+ Enformer  Thyroid         0.069276893 3    463   0.05516581
# 107 AbExp\n+ Enformer  Uterus          0.017997318 3     35   0.05516581
# 108 AbExp\n+ Enformer  Vagina          0.002402326 3     32   0.05516581
#     auc_median auc_std
# 1   0.05833111 0.03276041
# 2   0.05833111 0.03276041
# 3   0.05833111 0.03276041
# 4   0.05833111 0.03276041
# 5   0.05833111 0.03276041
# 6   0.05833111 0.03276041
# 7   0.05833111 0.03276041
# 8   0.05833111 0.03276041
# 9   0.05833111 0.03276041
# 10  0.05833111 0.03276041
# 11  0.05833111 0.03276041
# 12  0.05833111 0.03276041
# 13  0.05833111 0.03276041
# 14  0.05833111 0.03276041
# 15  0.05833111 0.03276041
# 16  0.05833111 0.03276041
# 17  0.05833111 0.03276041
# 18  0.05833111 0.03276041
# 19  0.05833111 0.03276041
# 20  0.05833111 0.03276041
# 21  0.05833111 0.03276041
# 22  0.05833111 0.03276041
# 23  0.05833111 0.03276041
# 24  0.05833111 0.03276041
# 25  0.05833111 0.03276041
# 26  0.05833111 0.03276041
# 27  0.05833111 0.03276041
# 28  0.06167374 0.03636921
# 29  0.06167374 0.03636921
# 30  0.06167374 0.03636921
# ⋮   ⋮          ⋮
# 79  0.06006703 0.03130272
# 80  0.06006703 0.03130272
# 81  0.06006703 0.03130272
# 82  0.05704477 0.03014341
# 83  0.05704477 0.03014341
# 84  0.05704477 0.03014341
# 85  0.05704477 0.03014341
# 86  0.05704477 0.03014341
# 87  0.05704477 0.03014341
# 88  0.05704477 0.03014341
# 89  0.05704477 0.03014341
# 90  0.05704477 0.03014341
# 91  0.05704477 0.03014341
# 92  0.05704477 0.03014341
# 93  0.05704477 0.03014341
# 94  0.05704477 0.03014341
# 95  0.05704477 0.03014341
# 96  0.05704477 0.03014341
# 97  0.05704477 0.03014341
# 98  0.05704477 0.03014341
# 99  0.05704477 0.03014341
# 100 0.05704477 0.03014341
# 101 0.05704477 0.03014341
# 102 0.05704477 0.03014341
# 103 0.05704477 0.03014341
# 104 0.05704477 0.03014341
# 105 0.05704477 0.03014341
# 106 0.05704477 0.03014341
# 107 0.05704477 0.03014341
# 108 0.05704477 0.03014341

# %%
tissue_performance[,.(num_tissues=.N, median_auc=median(`auc`)), by="model"][order(`median_auc`)]
# Out:
#   model              num_tissues median_auc
# 1 AbExp\n+ Enformer  27          0.05704477
# 2 AbExp              27          0.05833111
# 3 AbExp\n+ Aparent2  27          0.06006703
# 4 AbExp\n+ SpeciesLM 27          0.06167374

# %%
auc_df = unique(prc_df[, .(`model`, `auc`, `idx`)])
auc_df[order(`auc`)]
# Out:
#   model              auc        idx
# 1 AbExp              0.06860093 0
# 2 AbExp\n+ Enformer  0.06990387 3
# 3 AbExp\n+ Aparent2  0.07108169 2
# 4 AbExp\n+ SpeciesLM 0.07210243 1

# %%
options(repr.plot.width=15, repr.plot.height=8)

# %%
auc_bar_plot = (
    ggplot(auc_df, aes(x=reorder(`model`, `auc`), y=`auc`, fill=`model`))
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_bar(stat="identity")
    + scale_y_continuous(labels = scales::percent)
    # + scale_x_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + xlim(-0.05, 1.05)
    # + ylim(-0.05, 1.05)
    + xlab("")
    + THEME
    + background_grid()
    + coord_flip()
)
auc_bar_plot
# Out:
# plot without title

# %%
# tissue_performance = tissue_performance %>% mutate(model = reorder(`model`, `auc`, FUN = median))

# %%
comparisons = list(
    # Comparisons against the baseline AbExp
    # c('AbExp', 'AbExp\n+ TSS'),
    # c('AbExp', 'AbExp\n+ PAS'),
    # c('AbExp', 'AbExp\n+ PAS + TSS'),
    c('AbExp', 'AbExp\n+ Enformer'),
    c('AbExp', 'AbExp\n+ Aparent2'),
    c('AbExp', 'AbExp\n+ SpeciesLM'),
    # compare tss and pas annotations against the models
    # c('AbExp\n+ TSS', 'AbExp\n+ Enformer'),
    # c('AbExp\n+ TSS', 'AbExp\n+ Aparent2'),
    # c('AbExp\n+ TSS', 'AbExp\n+ SpeciesLM'),
    # # compare the models with each other
    c('AbExp\n+ Enformer', 'AbExp\n+ SpeciesLM'),
    c('AbExp\n+ Aparent2', 'AbExp\n+ SpeciesLM')
)

# %%
stat.test <- (
    tissue_performance
    %>% wilcox_test(`auc` ~ `model`, paired=TRUE, comparisons = comparisons, alternative='less') 
    %>% add_significance("p")
)


# Add p-values to a boxplot
stat.test <- stat.test %>% add_xy_position(x = "model")
stat.test$all_lower = apply(stat.test, 1, function(x) all_lower(tissue_performance, "model", "auc", x$`group2`, x$`group1`) | all_lower(tissue_performance, "model", "auc", x$`group1`, x$`group2`))
stat.test$p_label = paste0(ifelse(stat.test$all_lower, "P < ", "P = "), lapply(stat.test$p, function(x) fancy_scientific(x, 3)))
as.data.table(stat.test)
# Out:
#   .y. group1            group2             n1 n2 statistic p        p.adj
# 1 auc AbExp             AbExp\n+ Enformer  27 27 145       1.51e-01 0.302000
# 2 auc AbExp             AbExp\n+ Aparent2  27 27  53       2.99e-04 0.000897
# 3 auc AbExp             AbExp\n+ SpeciesLM 27 27  35       3.17e-05 0.000158
# 4 auc AbExp\n+ Enformer AbExp\n+ SpeciesLM 27 27  48       1.69e-04 0.000676
# 5 auc AbExp\n+ Aparent2 AbExp\n+ SpeciesLM 27 27 169       3.22e-01 0.322000
#   p.adj.signif p.signif y.position groups                                 xmin
# 1 ns           ns       0.17384    AbExp            , AbExp\n+ Enformer   1
# 2 ***          ***      0.18239    AbExp            , AbExp\n+ Aparent2   1
# 3 ***          ****     0.19094    AbExp             , AbExp\n+ SpeciesLM 1
# 4 ***          ***      0.19949    AbExp\n+ Enformer , AbExp\n+ SpeciesLM 2
# 5 ns           ns       0.20804    AbExp\n+ Aparent2 , AbExp\n+ SpeciesLM 3
#   xmax all_lower p_label
# 1 2    FALSE     P = 0.151
# 2 3    FALSE     P = 2.99x10⁻⁴
# 3 4    FALSE     P = 3.17x10⁻⁵
# 4 4    FALSE     P = 1.69x10⁻⁴
# 5 4    FALSE     P = 0.322

# %%
seq(from=0.15,by=0.02, length.out=length(comparisons))
# Out:
# [1] 0.15 0.17 0.19 0.21 0.23

# %%
stat.test$y.position = seq(from=0.13,by=0.02, length.out=length(comparisons))
# stat.test$y.position = c(0.17, 0.13, 0.15, 0.19, 
#                          0.21, 0.23, 
#                          0.25, 0.29, 0.27)

# %%
options(repr.plot.width=5, repr.plot.height=4, repr.plot.res=300)
auc_plot <- (
    ggplot(tissue_performance, aes(y=`auc`, x=`model`))
    # + scale_fill_manual(values=color_list)
    # + scale_fill_manual(name = element_blank(), values=renamed_colors)
    + geom_boxplot(aes(fill=`model`))
    + scale_y_continuous(
        limits=c(0, max(tissue_performance$auc) * 1.3),
        labels=scales::percent
    )
    # + scale_y_discrete(labels = function(x) {
    #     x %>% str_replace_all(" \\+", "\n+") %>% str_replace_all(" \\(", "\n(")
    # })
    # + geom_jitter(alpha=0.5)
    + THEME
    + background_grid(major = "xy")
    # + theme(legend.title = element_blank(), axis.title.y=element_blank())
    + theme(legend.title = element_blank())
    + theme(legend.position = "none")
    + coord_flip()
    + labs(
        y="AUPRC",
        x=element_blank(),
        title="Across tissues"
    )
    + stat_pvalue_manual(stat.test, label = "{p_label}", coord.flip=TRUE)
    # + stat_compare_means(
    #     comparisons = list(
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "LOFTEE"),
    #         c(rename_models[["LOFTEE+CADD+consequences"]], "CADD")
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP"]], rename_models[["LOFTEE+CADD+VEP"]])
    #         # c(rename_models[["LOFTEE+CADD+weighted VEP+dispersion"]], rename_models[["LOFTEE+CADD+weighted VEP"]])
    #         # c("AbExp-DNA:\nvariant effects + tissue-specificity + AbSplice + SV", "variant effects + tissue-specificity + AbSplice")
    #     ),
    #     method = "wilcox.test",
    #     paired=TRUE,
    # )
)
auc_plot
# Out:
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <b5>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# plot without title

# %%
width=5
height=4

path = paste(output_path, 'single_auc_under', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), auc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_auc_under..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”

# %%
options(repr.plot.width=3, repr.plot.height=4, repr.plot.res=300)
prc_plot = (
    ggplot(prc_df, aes(x=`recall`, y=`precision`))
    + geom_step(aes(color=reorder(`model`, `idx`)), linewidth=LINESIZE, direction="vh")
    # + scale_color_manual(name = element_blank(), values=nonbinary_model_colors)
    # + new_scale("color")
    + THEME
    + background_grid(major = "xy", minor = "xy")
    + scale_x_continuous(
        limits = c(0, 1),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + scale_y_continuous(
        limits = c(0, 1),
        # breaks = seq(0, 1, 0.2),
        # minor_breaks = seq(0, 1, 0.2)
        labels=scales::percent
    )
    + coord_cartesian(xlim=c(0, 0.4), ylim = c(0, 1))
    + scale_shape_manual(name=element_blank(), values=c(4, 4))
    + guides(color=guide_legend(order = 1), shape=guide_legend(order = 2))
    + theme(
        #legend.position="right",
        legend.title=element_blank(),
        legend.position = c(0.95, 0.95),
        legend.justification = c("right", "top"),
        legend.key.height = unit(1, "cm")
        # axis.text.x=element_text(angle=45, hjust=1),
    )
    + labs(
        x='Recall',
        y='Precision',
        title="All tissues"
    )
)
prc_plot
# Out:
# Warning message:
# “A numeric `legend.position` argument in `theme()` was deprecated in ggplot2
# 3.5.0.
# ℹ Please use the `legend.position.inside` argument of `theme()` instead.”
# plot without title

# %%
width=3
height=4

path = paste(output_path, 'single_prc_under', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), prc_plot, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_prc_under..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”

# %%
options(repr.plot.width=8, repr.plot.height=4, repr.plot.res=300)
p <- plot_grid(auc_plot, prc_plot, rel_widths = c(5, 3))
p
# Out:
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 2.99x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 3.17x10⁻⁵' in 'mbcsToSbcs': dot substituted for <b5>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <e2>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <81>”
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on 'P = 1.69x10⁻⁴' in 'mbcsToSbcs': dot substituted for <b4>”
# plot without title

# %%
width=8
height=4

path = paste(output_path, 'single_prc_auc_under', sep='/')
print(paste0("Saving to ", path, "..."))
ggsave(paste0(path, ".png"), p, width = width, height = height, dpi=600, type='cairo')
# Out:
# [1] "Saving to /data/nasif12/home_if12/tsi/projects/kipoi_veff_analysis/plots/single_prc_auc_under..."
# Warning message:
# “Using ragg device as default. Ignoring `type` and `antialias` arguments”
